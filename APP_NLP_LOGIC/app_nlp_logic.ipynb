# %%
import nltk
import re
from nltk.tokenize import sent_tokenize, word_tokenize, WhitespaceTokenizer, SExprTokenizer, TabTokenizer   
from nltk import PorterStemmer
from nltk import word_tokenize
from nltk.corpus import stopwords
import pandas as pd
from nltk.corpus import words, stopwords

# %%
test_lyrics = "When you're all alone and blue. No one to tell your troubles to\
Remember me, I'm the one who loves you\
When this world turns you down\
Not a true friend can be found\
Remember me, I'm the one who loves you\
And through all kinds of weather\
You'll find, I'll NEVER change.\
Through the sunshine and the shadows\
I'll always be 5 the same\
We're together right or wrong\
Where you go I'll 400 tag along\
Remember me, I'm the one who loves you\
And through all kinds of weather?\
You'll find, I'll never change\
Through the sunshine and the shadows\
I'll always be the same\
We're together right or wrong\
Where you go I'll tag along!\
Remember me, I'm the one who loves you"

# %%
# How do we make sure the tabs and spaces don't precent the text from being a string?
# # Create space at the end of lines
# end_of_sen = re.compile(r'^[A-Z].*[\t]$', re.M)
# re.findall(test_lyrics)
# print(re.match(end_of_sen, test_lyrics))

# %%
# Aline's code
#def lyrics_BoW():
#     lyrics = "My house is beautiful"
#     # Tokenizing
#     words = nltk.word_tokenize(lyrics)
#     # Create an object of class PorterStemmer; set stopwords from NLTK as variable
#     porter = PorterStemmer()
#     stop_words = stopwords.words('english')
#     # Removing stopwords and stemming the remaining ones
#     filtered_lyrics = [porter.stem(w) for w in words if not w in stop_words]
#     # Creating frequency of each word and storing in dataframe
#     wordfreq = {}
#     for word in filtered_lyrics:
#         if word not in wordfreq.keys():
#             wordfreq[word] = 1
#         else:
#             wordfreq[word] += 1
#     # Updating dictionary with the genre (user input)
#     genre = "rock"
#     wordfreq.update({"genre": genre})
#     # Adding dictionary to dataframe to be used in the ML Model
#     wordfreq_df = pd.DataFrame(data=wordfreq, index=[0])
#     return wordfreq_df

# %%
# Create function
def lyrics_Bow():
    #Create an empty model_df. This list is going to be updated with final_df.columns.values
    model_df = pd.DataFrame(columns=['abov', 'accept', 'ach', 'across', 'act', 'action', 'addict', 'admit', 
                                     'ador', 'afraid', 'age', 'ago', 'ahead', 'aim', 'air', 'album', 'algo', 
                                     'aliv', 'alla', 'alma', 'almost', 'alon', 'along', 'alreadi', 'alright', 
                                     'although', 'alway', 'amaz', 'america', 'american', 'amigo', 'amo', 'amor', 
                                     'amour', 'angel', 'anger', 'ani', 'anim', 'anoth', 'answer', 'ant', 
                                     'anybodi', 'anymor', 'anyon', 'anyth', 'anyway', 'anywher', 'apart', 
                                     'appear', 'arm', 'around', 'arriv', 'art', 'ash', 'ask', 'asleep', 'ass', 
                                     'att', 'attack', 'aus', 'aux', 'awak', 'away', 'babe', 'babi', 'back', 'bad',
                                     'bag', 'ball', 'band', 'bang', 'bank', 'bar', 'bare', 'bass', 'battl', 
                                     'beach', 'bear', 'beast', 'beat', 'beauti', 'becam', 'becaus', 'becom', 
                                     'bed', 'beer', 'befor', 'beg', 'began', 'begin', 'begun', 'behind', 'bei', 
                                     'believ', 'bell', 'belong', 'bend', 'beneath', 'besid', 'beso', 'best', 
                                     'bet', 'betray', 'better', 'beyond', 'big', 'bigger', 'bill', 'bin', 'bird', 
                                     'birth', 'bis', 'bist', 'bit', 'bitch', 'bite', 'bitter', 'black', 'blame', 
                                     'blast', 'bleed', 'bless', 'blind', 'block', 'blood', 'bloodi', 'blow', 
                                     'blue', 'boat', 'bodi', 'bomb', 'bon', 'bone', 'boogi', 'book', 'boom', 
                                     'boot', 'bop', 'bore', 'born', 'boss', 'bother', 'bottl', 'bottom', 'bought',
                                     'bounc', 'bound', 'bout', 'bow', 'box', 'boy', 'brain', 'brand', 'brave', 
                                     'break', 'breath', 'breez', 'brick', 'bridg', 'bright', 'bring', 'broke', 
                                     'broken', 'brother', 'brought', 'brown', 'buck', 'build', 'built', 'bullet', 
                                     'buri', 'burn', 'burnin', 'bus', 'busi', 'bust', 'but', 'buy', 'bye', 'cage',
                                     'call', 'callin', 'calm', 'came', 'candi', 'candl', 'cannot', 'cant', 'car',
                                     'card', 'care', 'carri', 'casa', 'case', 'cash', 'cast', 'cat', 'catch', 
                                     'caught', 'caus', 'cell', 'certain', 'ces', 'cest', 'chain', 'chair', 
                                     'chanc', 'chang', 'charm', 'chase', 'che', 'cheap', 'cheat', 'check', 
                                     'chest', 'chi', 'chick', 'child', 'children', 'chill', 'choic', 'choke', 
                                     'choos', 'chorus', 'chose', 'christ', 'church', 'cigarett', 'circl', 'citi', 
                                     'claim', 'clap', 'class', 'clean', 'clear', 'climb', 'clock', 'close', 
                                     'closer', 'cloth', 'cloud', 'clown', 'club', 'coast', 'coffe', 'cold', 
                                     'color', 'com', 'come', 'comfort', 'comin', 'comm', 'como', 'compani', 
                                     'complet', 'con', 'confess', 'confus', 'connect', 'constant', 'control', 
                                     'convers', 'cool', 'cop', 'corner', 'cos', 'cost', 'could', 'count', 
                                     'countri', 'coupl', 'cours', 'cover', 'crack', 'crash', 'crawl', 'crazi', 
                                     'creat', 'creep', 'crew', 'cri', 'crime', 'cross', 'crowd', 'crown', 'cruel',
                                     'crush', 'cryin', 'cup', 'cure', 'curs', 'cut', 'dad', 'daddi', 'dame', 
                                     'damn', 'dan', 'danc', 'dancin', 'danger', 'dare', 'dark', 'darl', 'darlin', 
                                     'das', 'dat', 'date', 'daughter', 'dawn', 'day', 'dead', 'deal', 'dear', 
                                     'death', 'decid', 'deep', 'deeper', 'del', 'dem', 'demand', 'demon', 'den', 
                                     'deni', 'der', 'des', 'desert', 'deserv', 'desir', 'destini', 'destroy', 
                                     'destruct', 'det', 'devil', 'dia', 'diamond', 'dice', 'dick', 'did', 'die', 
                                     'differ', 'dig', 'dime', 'dir', 'dire', 'direct', 'dirt', 'dirti', 'dis', 
                                     'disappear', 'diseas', 'disguis', 'distanc', 'distant', 'dit', 'divin', 
                                     'doctor', 'doe', 'dog', 'doin', 'dollar', 'dolor', 'done', 'don’t', 'doo', 
                                     'door', 'dope', 'dos', 'doubl', 'doubt', 'dove', 'drag', 'draw', 'dream', 
                                     'dress', 'dri', 'drift', 'drink', 'drive', 'drop', 'drown', 'drug', 'drum', 
                                     'drunk', 'due', 'dumb', 'dun', 'dust', 'ear', 'earli', 'earth', 'eas', 
                                     'easi', 'east', 'eat', 'echo', 'edg', 'eight', 'either', 'electr', 'ell', 
                                     'ella', 'els', 'embrac', 'emot', 'empti', 'encor', 'end', 'endless', 'enemi',
                                     'enjoy', 'enough', 'enter', 'entr', 'era', 'eras', 'ere', 'escap', 'est', 
                                     'esto', 'etern', 'even', 'ever', 'everi', 'everybodi', 'everyday', 'everyon',
                                     'everyth', 'everywher', 'evil', 'exact', 'except', 'excus', 'exist', 'expect',
                                     'explain', 'eye', 'face', 'fact', 'fade', 'fai', 'fail', 'fair', 'fait', 
                                     'faith', 'fake', 'fall', 'fallen', 'fallin', 'fals', 'fame', 'famili', 'fan',
                                     'fantasi', 'far', 'fast', 'faster', 'fat', 'fate', 'father', 'fault', 'favor',
                                     'favorit', 'fear', 'fed', 'feed', 'feel', 'feelin', 'feet', 'fell', 'felt', 
                                     'fever', 'field', 'fight', 'figur', 'fill', 'fin', 'final', 'find', 'fine', 
                                     'finger', 'finish', 'fire', 'first', 'fish', 'fist', 'fit', 'five', 'fix', 
                                     'flame', 'flash', 'flesh', 'fli', 'flight', 'flip', 'float', 'floor', 'flow',
                                     'flower', 'foi', 'folk', 'follow', 'food', 'fool', 'foot', 'for', 'forc', 
                                     'forev', 'forget', 'forgiv', 'forgot', 'forgotten', 'form', 'fort', 'fortun',
                                     'forward', 'found', 'four', 'frame', 'freak', 'free', 'freedom', 'freez', 
                                     'fresh', 'friend', 'front', 'frozen', 'fuck', 'fuckin', 'fue', 'full', 'fun',
                                     'funk', 'funki', 'funni', 'futur', 'gain', 'gal', 'game', 'gang', 'gangsta', 
                                     'garden', 'gate', 'gather', 'gave', 'generat', 'gent', 'gentl', 'get', 
                                     'gettin', 'ghetto', 'ghost', 'gift', 'gimm', 'girl', 'girlfriend', 'give', 
                                     'given', 'givin', 'glad', 'glass', 'glori', 'glow', 'god', 'goe', 'goin', 
                                     'gold', 'golden', 'gon', 'gone', 'gonna', 'good', 'goodby', 'got', 'gotta', 
                                     'grab', 'grace', 'grand', 'grass', 'grave', 'gray', 'great', 'greatest', 
                                     'green', 'grew', 'grey', 'grip', 'groov', 'ground', 'grow', 'grown', 'guess',
                                     'guid', 'guilti', 'guitar', 'gun', 'gut', 'guy', 'hab', 'hace', 'hair', 
                                     'half', 'hall', 'hallelujah', 'hammer', 'han', 'hand', 'handl', 'hang', 
                                     'happen', 'happi', 'har', 'hard', 'harder', 'hast', 'hat', 'hate', 'haunt', 
                                     'hay', 'head', 'heal', 'hear', 'heard', 'heart', 'heartach', 'heat', 'heaven',
                                     'heavi', 'held', 'hell', 'hello', 'help', 'hero', 'het', 'hey', 'hidden', 
                                     'hide', 'high', 'higher', 'highway', 'hill', 'hip', 'histori', 'hit', 'hoe', 
                                     'hold', 'hole', 'holi', 'hollow', 'home', 'homi', 'honest', 'honey', 'hoo', 
                                     'hood', 'hook', 'hop', 'hope', 'hora', 'hors', 'hot', 'hour', 'hous', 'how',
                                     'hoy', 'huh', 'human', 'hungri', 'hurri', 'hurt', 'ice', 'idea', 'ignor', 
                                     'ill', 'illus', 'ima', 'imag', 'imagin', 'insan', 'insid', 'instead', 
                                     'instrument', 'intent', 'island', 'it’', 'i’m', 'jack', 'jag', 'jai', 'jam', 
                                     'jean', 'jesus', 'job', 'joe', 'john', 'johnni', 'join', 'joke', 'journey', 
                                     'joy', 'judg', 'jump', 'kan', 'keep', 'kept', 'key', 'kick', 'kid', 'kill', 
                                     'killer', 'kind', 'kinda', 'king', 'kingdom', 'kiss', 'knee', 'knew', 'knife',
                                     'knock', 'know', 'known', 'lack', 'ladi', 'laid', 'land', 'lang', 'las', 
                                     'last', 'late', 'later', 'laugh', 'laughter', 'law', 'lay', 'lead', 'lean', 
                                     'learn', 'least', 'leav', 'leavin', 'left', 'leg', 'les', 'less', 'lesson', 
                                     'let', 'letter', 'liar', 'lick', 'lie', 'life', 'lifetim', 'lift', 'light', 
                                     'like', 'lil', 'limit', 'line', 'lip', 'listen', 'littl', 'live', 'livin', 
                                     'load', 'lock', 'lone', 'lonesom', 'long', 'longer', 'look', 'lookin', 'loos',
                                     'lord', 'los', 'lose', 'lost', 'lot', 'loud', 'love', 'lover', 'lovin', 
                                     'low', 'luck', 'lucki', 'luna', 'lust', 'luz', 'lyric', 'machin', 'mad', 
                                     'made', 'magic', 'mai', 'main', 'make', 'makin', 'mal', 'mama', 'man', 'mani',
                                     'mano', 'mar', 'march', 'mari', 'mark', 'marri', 'mas', 'mass', 'master', 
                                     'match', 'matter', 'may', 'mayb', 'mean', 'meant', 'med', 'meet', 'mein', 
                                     'melodi', 'melt', 'memori', 'men', 'mental', 'merci', 'mes', 'mess', 'messag',
                                     'met', 'metal', 'mia', 'mic', 'mich', 'middl', 'midnight', 'mig', 'might', 
                                     'mighti', 'mile', 'million', 'mind', 'mine', 'minut', 'mir', 'mira', 'miracl',
                                     'mirror', 'mis', 'miseri', 'miss', 'mission', 'mistak', 'mit', 'mix', 'moi', 
                                     'mom', 'moment', 'mon', 'mond', 'money', 'monkey', 'month', 'mood', 'moon', 
                                     'moonlight', 'morn', 'mornin', 'mot', 'mother', 'motherfuck', 'motion', 
                                     'mountain', 'mouth', 'move', 'movi', 'movin', 'much', 'murder', 'music', 
                                     'must', 'mysteri', 'nach', 'nadi', 'nah', 'nail', 'nake', 'name', 'nation', 
                                     'natur', 'near', 'neck', 'need', 'nest', 'never', 'new', 'news', 'next', 
                                     'nice', 'nigga', 'niggaz', 'night', 'nightmar', 'nine', 'nobodi', 'noi', 
                                     'nois', 'non', 'none', 'noon', 'north', 'nos', 'nose', 'not', 'note', 'noth',
                                     'nothin', 'notic', 'nous', 'nowher', 'numb', 'number', 'ocean', 'och', 'oder',
                                     'offer', 'okay', 'old', 'older', 'onc', 'one', 'onli', 'onto', 'ooh', 'open',
                                     'order', 'out', 'outsid', 'outta', 'pack', 'page', 'paid', 'pain', 'paint', 
                                     'papa', 'paper', 'par', 'para', 'paradis', 'park', 'part', 'parti', 'pas', 
                                     'pass', 'passion', 'past', 'path', 'pay', 'peac', 'pena', 'peopl', 'per', 
                                     'perfect', 'person', 'petit', 'phone', 'pick', 'pictur', 'pie', 'piec', 
                                     'pill', 'piss', 'piti', 'place', 'plain', 'plan', 'plane', 'planet', 'play', 
                                     'playa', 'playin', 'pleas', 'pleasur', 'plus', 'pocket', 'poco', 'poi', 
                                     'point', 'poison', 'polic', 'poor', 'pop', 'por', 'posit', 'possibl', 'pound',
                                     'pour', 'power', 'pra', 'prais', 'pray', 'prayer', 'precious', 'prepar', 
                                     'present', 'press', 'pressur', 'pretend', 'pretti', 'price', 'pride', 
                                     'prison', 'probabl', 'problem', 'promis', 'protect', 'proud', 'prove', 
                                     'pull', 'pump', 'punk', 'pure', 'push', 'pussi', 'put', 'que', 'queen', 
                                     'question', 'qui', 'quick', 'quiet', 'quil', 'quit', 'race', 'radio', 'rage',
                                     'rain', 'rainbow', 'rais', 'ran', 'rap', 'rapper', 'rat', 'rather', 'reach', 
                                     'read', 'readi', 'real', 'realiti', 'realiz', 'realli', 'reason', 'record', 
                                     'red', 'reflect', 'refrain', 'refus', 'regret', 'reign', 'relax', 'releas', 
                                     'religion', 'remain', 'rememb', 'remind', 'repeat', 'resist', 'respect', 
                                     'rest', 'return', 'reveal', 'revolut', 'rhyme', 'rhythm', 'rich', 'ride', 
                                     'right', 'ring', 'rip', 'rise', 'river', 'road', 'rock', 'rockin', 'roll', 
                                     'rollin', 'romanc', 'room', 'root', 'rose', 'rot', 'rough', 'round', 'ruin', 
                                     'rule', 'run', 'runnin', 'rush', 'sabe', 'saber', 'sacrific', 'sad', 'safe', 
                                     'sai', 'said', 'sail', 'saint', 'sale', 'san', 'sand', 'sang', 'santa', 
                                     'sat', 'satan', 'satisfi', 'saturday', 'save', 'saw', 'say', 'sayin', 'scar',
                                     'scare', 'scene', 'school', 'scratch', 'scream', 'screen', 'sea', 'search', 
                                     'season', 'seat', 'second', 'secret', 'see', 'seed', 'seek', 'seem', 'seen', 
                                     'sein', 'self', 'sell', 'sen', 'send', 'sens', 'sent', 'ser', 'sera', 'serv',
                                     'set', 'settl', 'seven', 'sex', 'sexi', 'shade', 'shadow', 'shake', 'shall',
                                     'shame', 'shape', 'share', 'shatter', 'shed', 'shelter', 'shi', 'shine', 
                                     'ship', 'shit', 'shock', 'shoe', 'shoot', 'shop', 'shore', 'short', 'shot', 
                                     'shoulder', 'shout', 'show', 'shut', 'sick', 'side', 'sigh', 'sight', 'sign',
                                     'silenc', 'silent', 'silver', 'simpl', 'sin', 'sinc', 'sind', 'sing', 
                                     'singin', 'singl', 'sink', 'sister', 'sit', 'sittin', 'situat', 'six', 
                                     'skin', 'sky', 'slave', 'sleep', 'slide', 'slip', 'slow', 'slowli', 'small', 
                                     'smash', 'smell', 'smile', 'smoke', 'snake', 'snow', 'soft', 'sol', 'sold', 
                                     'soldier', 'solo', 'som', 'some', 'somebodi', 'someday', 'somehow', 'someon',
                                     'someth', 'somethin', 'sometim', 'somewher', 'son', 'song', 'soon', 'sorri', 
                                     'sorrow', 'soul', 'sound', 'south', 'soy', 'space', 'spark', 'speak', 
                                     'special', 'speed', 'spell', 'spend', 'spent', 'spill', 'spin', 'spirit', 
                                     'spit', 'split', 'spoken', 'spot', 'spread', 'spring', 'stage', 'stain', 
                                     'stand', 'star', 'stare', 'start', 'state', 'station', 'stay', 'steadi', 
                                     'steal', 'steel', 'step', 'stick', 'still', 'stole', 'stone', 'stood', 
                                     'stop', 'store', 'stori', 'storm', 'straight', 'strang', 'stranger', 
                                     'stream', 'street', 'strength', 'stress', 'strike', 'string', 'strong', 
                                     'stronger', 'struggl', 'stuck', 'stuff', 'stumbl', 'stupid', 'style', 'suck',
                                     'sucker', 'sudden', 'suffer', 'sugar', 'sui', 'suicid', 'suit', 'summer', 
                                     'sun', 'sunday', 'sunshin', 'super', 'suppos', 'sur', 'sure', 'surpris', 
                                     'surrend', 'surround', 'surviv', 'sus', 'swallow', 'swear', 'sweat', 'sweet',
                                     'swim', 'swing', 'switch', 'sword', 'system', 'tabl', 'tag', 'take', 'taken',
                                     'takin', 'tale', 'talk', 'talkin', 'tall', 'tan', 'tanto', 'tard', 'tast', 
                                     'taught', 'teach', 'tear', 'teeth', 'telephon', 'tell', 'tellin', 'temp', 
                                     'tempo', 'ten', 'tender', 'terror', 'tes', 'test', 'tha', 'than', 'thank', 
                                     'that', 'thee', 'thi', 'thin', 'thing', 'think', 'thinkin', 'though', 
                                     'thought', 'thousand', 'three', 'threw', 'thrill', 'throat', 'through', 
                                     'throw', 'thug', 'thunder', 'tick', 'ticket', 'tide', 'tie', 'tight', 'til', 
                                     'till', 'time', 'tip', 'tire', 'toda', 'today', 'toe', 'togeth', 'toi', 
                                     'told', 'tomorrow', 'ton', 'tongu', 'tonight', 'took', 'top', 'torn', 
                                     'total', 'touch', 'tough', 'tout', 'toward', 'town', 'toy', 'trace', 'track',
                                     'trade', 'train', 'trap', 'travel', 'treat', 'tree', 'tri', 'trick', 'trip', 
                                     'trist', 'trop', 'troubl', 'truck', 'true', 'truli', 'trust', 'truth', 
                                     'tryin', 'tune', 'turn', 'tus', 'twenti', 'twice', 'twist', 'two', 'type', 
                                     'ugli', 'una', 'und', 'underground', 'underneath', 'understand', 'unit', 
                                     'univers', 'unknown', 'unless', 'upon', 'use', 'vai', 'vain', 'valley', 
                                     'van', 'var', 'vas', 'vein', 'ven', 'ver', 'veri', 'vers', 'victim', 'vida', 
                                     'vie', 'view', 'vill', 'violenc', 'vision', 'vita', 'voi', 'voic', 'wait', 
                                     'waitin', 'wake', 'walk', 'walkin', 'wall', 'wander', 'wanna', 'want', 'war',
                                     'warm', 'warn', 'was', 'wash', 'wast', 'watch', 'water', 'wave', 'way', 'weak',
                                     'wear', 'weather', 'weed', 'week', 'weep', 'weight', 'welcom', 'well', 'welt',
                                     'went', 'west', 'wet', 'what', 'whatev', 'wheel', 'when', 'whenev', 'wherev',
                                     'whi', 'whip', 'whisper', 'white', 'whoa', 'whole', 'whose', 'wick', 'wide', 
                                     'wife', 'wild', 'will', 'win', 'wind', 'window', 'wine', 'wing', 'winter', 
                                     'wipe', 'wir', 'wire', 'wise', 'wish', 'wit', 'within', 'without', 'woke', 
                                     'woman', 'women', 'wonder', 'wont', 'woo', 'wood', 'word', 'work', 'workin', 
                                     'world', 'worri', 'wors', 'worst', 'worth', 'would', 'wound', 'wrap', 'wreck',
                                     'write', 'written', 'wrong', 'wrote', 'yea', 'yeah', 'year', 'yellow', 'yes', 
                                     'yesterday', 'yet', 'york', 'you', 'young', 'youth'])
    # User input 
    lyrics = test_lyrics
    # Tokenize by words
    words = nltk.word_tokenize(lyrics)
    # Create an object of class PorterStemmer; set stopwords from NLTK as variable
    porter = PorterStemmer()
    stop_words = stopwords.words('english')
    # Removing stopwords and stemming the remaining ones
    filtered_lyrics = [porter.stem(w) for w in words if not w in stop_words]
    # Creating frequency of each word and storing in dataframe
    wordfreq = {}
    for word in filtered_lyrics:
        if word not in wordfreq.keys():
            wordfreq[word] = 1
        else:
            wordfreq[word] += 1
        # Updating dictionary with the genre (user input)
    genre = "rock"
    wordfreq.update({"genre": genre})
        # Adding dictionary to dataframe to be used in the ML Model

    for key,value in wordfreq.items():
        if key in model_df.columns.values:
            model_df = model_df.append({key:value},ignore_index = True)
        elif key == "genre":
            model_df = model_df.append({key:value},ignore_index = True)

    model_df = model_df.fillna(0)

# %%
lyrics_Bow()
