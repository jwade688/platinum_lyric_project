# %%
import pandas as pd
import numpy as np
import psycopg2
from sqlalchemy import create_engine
import datetime
import re
from ipython_config import db_password

# %%
# Connect to database (Note: The package psychopg2 is required for Postgres to work with SQLAlchemy)
db_string = f"postgres://postgres:{db_password}@127.0.0.1:5432/Lyrics_Platinum"

engine = create_engine(db_string)

# %%
# Get database tables
print(engine.table_names())
# Out:
# ['Billboard_non_hit', 'Billboard_hit', 'Songs_rank', 'mock_data']

# %%
# Create dataframe for non-hit songs
bb_miss_data = engine.table_names()[0]
bb_miss_df = pd.read_sql_table(bb_miss_data,engine)
bb_miss_df.head()
# Out:
#    index  Unnamed: 0              msd_id        echo_nest_id  \
# 0      0           0  TRMMMYQ128F932D901  SOQMMHC12AB0180CB8
# 1      1           1  TRMMMBB12903CB7D21  SOEYRFT12AB018936C
# 2      2           2  TRMMMNS128F93548E1  SOYGNWH12AB018191E
# 3      3           3  TRMMMXJ12903CBF111  SOLJTLX12AB01890ED
# 4      4           4  TRMMMKI128F931D80D  SOSDCFG12AB0184647
#
#              artist               title  year
# 0  Faster Pussy cat        Silent Night  2003
# 1        Kris Kross   2 Da Beat Ch'yall  1993
# 2  3 Gars Su'l Sofa       L'antarctique  2007
# 3     Jorge Negrete  El hijo del pueblo  1997
# 4   Lena Philipsson                 006  1998

# %%
# Create dataframe for hit songs
bb_hit_data = engine.table_names()[1]
bb_hit_df = pd.read_sql_table(bb_hit_data,engine)
bb_hit_df.head()
# Out:
#    index  Unnamed: 0              msd_id        echo_nest_id  \
# 0      0           0  TRMMWJS12903CBB7F5  SOLBDWO12AB0188CC2
# 1      1           1  TRMMCDR128F423AB03  SOSZNRJ12A8AE46E38
# 2      2           2  TRMMRUB12903CA097C  SOGDEWJ12AB0184C06
# 3      3           4  TRMMFIS128E078EDEA  SOYURIX12A6701E960
# 4      4           7  TRMMNZH128F92CF7D0  SOXCAWC12A8C144428
#
#                       artist                           title  year  peak  \
# 0                  Aerosmith  Remember (Walking In The Sand)  1979     6
# 1  Michael Cera & Ellen Page             Anyone Else But You  2007     2
# 2               Brook Benton                       Lie To Me  1986    10
# 3                  Aerosmith                          Cryin'  1993    26
# 4               Buster Brown                      Sugar Babe  2002     2
#
#    weeks
# 0     67
# 1     91
# 2     13
# 3     12
# 4     99

# %%
# Create dataframe for rank songs dataset
songs_rank_data = engine.table_names()[2]
songs_rank_df = pd.read_sql_table(songs_rank_data,engine)
songs_rank_df.head()
# Out:
#    index     date                   title  \
# 0      0  6/21/18           4th Dimension
# 1      1  6/21/18  All Girls Are The Same
# 2      2  6/21/18                All Mine
# 3      3  6/21/18                   Alone
# 4      4  6/21/18                    Babe
#
#                                      artist  peakPos  lastPos  weeks  rank  \
# 0     KIDS SEE GHOSTS Featuring Louis Prima       42        0      1    42
# 1                                Juice WRLD       41       49      5    41
# 2                                Kanye West       11       11      2    31
# 3  Halsey Featuring Big Sean & Stefflon Don       70       73      9    74
# 4          Sugarland Featuring Taylor Swift       72        0      2    95
#
#      change
# 0       New
# 1         8
# 2       -20
# 3        -1
# 4  Re-Entry

# %%
# Drop columns 
songs_rank_df = songs_rank_df.drop(columns= ["peakPos","lastPos","change"],axis=1)
songs_rank_df.head()
# Out:
#    index     date                   title  \
# 0      0  6/21/18           4th Dimension
# 1      1  6/21/18  All Girls Are The Same
# 2      2  6/21/18                All Mine
# 3      3  6/21/18                   Alone
# 4      4  6/21/18                    Babe
#
#                                      artist  weeks  rank
# 0     KIDS SEE GHOSTS Featuring Louis Prima      1    42
# 1                                Juice WRLD      5    41
# 2                                Kanye West      2    31
# 3  Halsey Featuring Big Sean & Stefflon Don      9    74
# 4          Sugarland Featuring Taylor Swift      2    95

# %%
# Extract year from date column
songs_rank_df["year"] = pd.DatetimeIndex(songs_rank_df['date']).year
songs_rank_df = songs_rank_df.drop(["date"],axis=1)
songs_rank_df.head()
# Out:
#    index                   title                                    artist  \
# 0      0           4th Dimension     KIDS SEE GHOSTS Featuring Louis Prima
# 1      1  All Girls Are The Same                                Juice WRLD
# 2      2                All Mine                                Kanye West
# 3      3                   Alone  Halsey Featuring Big Sean & Stefflon Don
# 4      4                    Babe          Sugarland Featuring Taylor Swift
#
#    weeks  rank  year
# 0      1    42  2018
# 1      5    41  2018
# 2      2    31  2018
# 3      9    74  2018
# 4      2    95  2018

# %%
# Rename columns and add successful column
songs_rank_df =songs_rank_df.rename(columns= {"rank":"peak"})
songs_rank_df["Successful"] = 1
songs_rank_df.head()
# Out:
#    index                   title                                    artist  \
# 0      0           4th Dimension     KIDS SEE GHOSTS Featuring Louis Prima
# 1      1  All Girls Are The Same                                Juice WRLD
# 2      2                All Mine                                Kanye West
# 3      3                   Alone  Halsey Featuring Big Sean & Stefflon Don
# 4      4                    Babe          Sugarland Featuring Taylor Swift
#
#    weeks  peak  year  Successful
# 0      1    42  2018           1
# 1      5    41  2018           1
# 2      2    31  2018           1
# 3      9    74  2018           1
# 4      2    95  2018           1

# %%
# Change the order of columns
songs_rank_df = songs_rank_df[["artist","title","year","Successful"]]
songs_rank_df.sort_values(by="year")
# Out:
#                                      artist                           title  \
# 7488                           Ronnie Dyson               I Don't Wanna Cry
# 7497                          Bill Anderson  Where Have All Our Heroes Gone
# 7496                          The Intruders            This Is My Love Song
# 7495                  Engelbert Humperdinck                      Sweetheart
# 7494                              Bobby Vee                Sweet Sweetheart
# ...                                     ...                             ...
# 249                            XXXTENTACION                            Numb
# 250           Miguel Featuring Travis Scott                      Sky Walker
# 251                                  Khalid              Young Dumb & Broke
# 242               Selena Gomez X Marshmello                          Wolves
# 0     KIDS SEE GHOSTS Featuring Louis Prima                   4th Dimension
#
#       year  Successful
# 7488  1970           1
# 7497  1970           1
# 7496  1970           1
# 7495  1970           1
# 7494  1970           1
# ...    ...         ...
# 249   2018           1
# 250   2018           1
# 251   2018           1
# 242   2018           1
# 0     2018           1
#
# [20108 rows x 4 columns]

# %%
# Add Successful column to tables
bb_miss_df["Successful"] = 0
bb_miss_df.head()
# Out:
#    index  Unnamed: 0              msd_id        echo_nest_id  \
# 0      0           0  TRMMMYQ128F932D901  SOQMMHC12AB0180CB8
# 1      1           1  TRMMMBB12903CB7D21  SOEYRFT12AB018936C
# 2      2           2  TRMMMNS128F93548E1  SOYGNWH12AB018191E
# 3      3           3  TRMMMXJ12903CBF111  SOLJTLX12AB01890ED
# 4      4           4  TRMMMKI128F931D80D  SOSDCFG12AB0184647
#
#              artist               title  year  Successful
# 0  Faster Pussy cat        Silent Night  2003           0
# 1        Kris Kross   2 Da Beat Ch'yall  1993           0
# 2  3 Gars Su'l Sofa       L'antarctique  2007           0
# 3     Jorge Negrete  El hijo del pueblo  1997           0
# 4   Lena Philipsson                 006  1998           0

# %%
# Add Successful column to tables
bb_hit_df["Successful"] = 1
bb_hit_df.head()
# Out:
#    index  Unnamed: 0              msd_id        echo_nest_id  \
# 0      0           0  TRMMWJS12903CBB7F5  SOLBDWO12AB0188CC2
# 1      1           1  TRMMCDR128F423AB03  SOSZNRJ12A8AE46E38
# 2      2           2  TRMMRUB12903CA097C  SOGDEWJ12AB0184C06
# 3      3           4  TRMMFIS128E078EDEA  SOYURIX12A6701E960
# 4      4           7  TRMMNZH128F92CF7D0  SOXCAWC12A8C144428
#
#                       artist                           title  year  peak  \
# 0                  Aerosmith  Remember (Walking In The Sand)  1979     6
# 1  Michael Cera & Ellen Page             Anyone Else But You  2007     2
# 2               Brook Benton                       Lie To Me  1986    10
# 3                  Aerosmith                          Cryin'  1993    26
# 4               Buster Brown                      Sugar Babe  2002     2
#
#    weeks  Successful
# 0     67           1
# 1     91           1
# 2     13           1
# 3     12           1
# 4     99           1

# %%
# Connect all three dataframes
bb_df = pd.concat([bb_hit_df,bb_miss_df,songs_rank_df])
bb_df.head()
# Out:
#    index  Unnamed: 0              msd_id        echo_nest_id  \
# 0    0.0         0.0  TRMMWJS12903CBB7F5  SOLBDWO12AB0188CC2
# 1    1.0         1.0  TRMMCDR128F423AB03  SOSZNRJ12A8AE46E38
# 2    2.0         2.0  TRMMRUB12903CA097C  SOGDEWJ12AB0184C06
# 3    3.0         4.0  TRMMFIS128E078EDEA  SOYURIX12A6701E960
# 4    4.0         7.0  TRMMNZH128F92CF7D0  SOXCAWC12A8C144428
#
#                       artist                           title  year  peak  \
# 0                  Aerosmith  Remember (Walking In The Sand)  1979   6.0
# 1  Michael Cera & Ellen Page             Anyone Else But You  2007   2.0
# 2               Brook Benton                       Lie To Me  1986  10.0
# 3                  Aerosmith                          Cryin'  1993  26.0
# 4               Buster Brown                      Sugar Babe  2002   2.0
#
#    weeks  Successful
# 0   67.0           1
# 1   91.0           1
# 2   13.0           1
# 3   12.0           1
# 4   99.0           1

# %%
# Get null values
bb_df.isnull().sum()
bb_df.fillna(0)
# Out:
#        index  Unnamed: 0              msd_id        echo_nest_id  \
# 0        0.0         0.0  TRMMWJS12903CBB7F5  SOLBDWO12AB0188CC2
# 1        1.0         1.0  TRMMCDR128F423AB03  SOSZNRJ12A8AE46E38
# 2        2.0         2.0  TRMMRUB12903CA097C  SOGDEWJ12AB0184C06
# 3        3.0         4.0  TRMMFIS128E078EDEA  SOYURIX12A6701E960
# 4        4.0         7.0  TRMMNZH128F92CF7D0  SOXCAWC12A8C144428
# ...      ...         ...                 ...                 ...
# 20103    0.0         0.0                   0                   0
# 20104    0.0         0.0                   0                   0
# 20105    0.0         0.0                   0                   0
# 20106    0.0         0.0                   0                   0
# 20107    0.0         0.0                   0                   0
#
#                           artist                           title  year  peak  \
# 0                      Aerosmith  Remember (Walking In The Sand)  1979   6.0
# 1      Michael Cera & Ellen Page             Anyone Else But You  2007   2.0
# 2                   Brook Benton                       Lie To Me  1986  10.0
# 3                      Aerosmith                          Cryin'  1993  26.0
# 4                   Buster Brown                      Sugar Babe  2002   2.0
# ...                          ...                             ...   ...   ...
# 20103           The Soup Dragons                        I'm Free  1990   0.0
# 20104                      Vixen                Love Is A Killer  1990   0.0
# 20105                 Paul Young                         Oh Girl  1990   0.0
# 20106                      Kyper                     Tic-Tac-Toe  1990   0.0
# 20107           Vaughan Brothers                       Tick Tock  1990   0.0
#
#        weeks  Successful
# 0       67.0           1
# 1       91.0           1
# 2       13.0           1
# 3       12.0           1
# 4       99.0           1
# ...      ...         ...
# 20103    0.0           1
# 20104    0.0           1
# 20105    0.0           1
# 20106    0.0           1
# 20107    0.0           1
#
# [115175 rows x 10 columns]

# %%
bb_df.shape
# Out:
# (115175, 10)

# %%
# Capitalize artist and title columns
bb_df['artist'] = bb_df['artist'].str.upper()
bb_df['title'] = bb_df['title'].str.upper()
bb_df.head()
# Out:
#    index  Unnamed: 0              msd_id        echo_nest_id  \
# 0    0.0         0.0  TRMMWJS12903CBB7F5  SOLBDWO12AB0188CC2
# 1    1.0         1.0  TRMMCDR128F423AB03  SOSZNRJ12A8AE46E38
# 2    2.0         2.0  TRMMRUB12903CA097C  SOGDEWJ12AB0184C06
# 3    3.0         4.0  TRMMFIS128E078EDEA  SOYURIX12A6701E960
# 4    4.0         7.0  TRMMNZH128F92CF7D0  SOXCAWC12A8C144428
#
#                       artist                           title  year  peak  \
# 0                  AEROSMITH  REMEMBER (WALKING IN THE SAND)  1979   6.0
# 1  MICHAEL CERA & ELLEN PAGE             ANYONE ELSE BUT YOU  2007   2.0
# 2               BROOK BENTON                       LIE TO ME  1986  10.0
# 3                  AEROSMITH                          CRYIN'  1993  26.0
# 4               BUSTER BROWN                      SUGAR BABE  2002   2.0
#
#    weeks  Successful
# 0   67.0           1
# 1   91.0           1
# 2   13.0           1
# 3   12.0           1
# 4   99.0           1

# %%
# Create regex to find "Featuring" artists
feat_string = r'\s[F][E][A][T][U][R][E][S]|\s[F][E][A][T][U][R][I][N][G]|\s[F][E][A][T]\.'

# %%
# Split artist column to get the featuring artists
bb_df = pd.concat([bb_df,bb_df.title.str.split(feat_string,expand=True)],1)

# keep only the top 3 artists
bb_df = bb_df.drop(bb_df.columns[12:15], axis=1)

# #rename the columns
bb_df = bb_df.rename(columns={0: 'title_clean', 1: 'artist_feat'})
bb_df.head()
# Out:
#    index  Unnamed: 0              msd_id        echo_nest_id  \
# 0    0.0         0.0  TRMMWJS12903CBB7F5  SOLBDWO12AB0188CC2
# 1    1.0         1.0  TRMMCDR128F423AB03  SOSZNRJ12A8AE46E38
# 2    2.0         2.0  TRMMRUB12903CA097C  SOGDEWJ12AB0184C06
# 3    3.0         4.0  TRMMFIS128E078EDEA  SOYURIX12A6701E960
# 4    4.0         7.0  TRMMNZH128F92CF7D0  SOXCAWC12A8C144428
#
#                       artist                           title  year  peak  \
# 0                  AEROSMITH  REMEMBER (WALKING IN THE SAND)  1979   6.0
# 1  MICHAEL CERA & ELLEN PAGE             ANYONE ELSE BUT YOU  2007   2.0
# 2               BROOK BENTON                       LIE TO ME  1986  10.0
# 3                  AEROSMITH                          CRYIN'  1993  26.0
# 4               BUSTER BROWN                      SUGAR BABE  2002   2.0
#
#    weeks  Successful                     title_clean artist_feat
# 0   67.0           1  REMEMBER (WALKING IN THE SAND)        None
# 1   91.0           1             ANYONE ELSE BUT YOU        None
# 2   13.0           1                       LIE TO ME        None
# 3   12.0           1                          CRYIN'        None
# 4   99.0           1                      SUGAR BABE        None

# %%
# Format artist column
bb_df['artist'] = bb_df['artist'].str.replace("&",",").str.replace("FEAT.",",").str.replace("FEATURING",",")
bb_df.head()
# Out:
#    index  Unnamed: 0              msd_id        echo_nest_id  \
# 0    0.0         0.0  TRMMWJS12903CBB7F5  SOLBDWO12AB0188CC2
# 1    1.0         1.0  TRMMCDR128F423AB03  SOSZNRJ12A8AE46E38
# 2    2.0         2.0  TRMMRUB12903CA097C  SOGDEWJ12AB0184C06
# 3    3.0         4.0  TRMMFIS128E078EDEA  SOYURIX12A6701E960
# 4    4.0         7.0  TRMMNZH128F92CF7D0  SOXCAWC12A8C144428
#
#                       artist                           title  year  peak  \
# 0                  AEROSMITH  REMEMBER (WALKING IN THE SAND)  1979   6.0
# 1  MICHAEL CERA , ELLEN PAGE             ANYONE ELSE BUT YOU  2007   2.0
# 2               BROOK BENTON                       LIE TO ME  1986  10.0
# 3                  AEROSMITH                          CRYIN'  1993  26.0
# 4               BUSTER BROWN                      SUGAR BABE  2002   2.0
#
#    weeks  Successful                     title_clean artist_feat
# 0   67.0           1  REMEMBER (WALKING IN THE SAND)        None
# 1   91.0           1             ANYONE ELSE BUT YOU        None
# 2   13.0           1                       LIE TO ME        None
# 3   12.0           1                          CRYIN'        None
# 4   99.0           1                      SUGAR BABE        None

# %%
# Concatenate artist column by comma
bb_df=pd.concat([bb_df,bb_df.artist.str.split(',',expand=True)],1)

# keep only the top 3 artists
bb_df = bb_df.drop(bb_df.columns[15:59], axis=1)

#rename the columns
bb_df = bb_df.rename(columns={0: 'artist_1', 1: 'artist_2', 2: 'artist_3'})
bb_df.head()
# Out:
#    index  Unnamed: 0              msd_id        echo_nest_id  \
# 0    0.0         0.0  TRMMWJS12903CBB7F5  SOLBDWO12AB0188CC2
# 1    1.0         1.0  TRMMCDR128F423AB03  SOSZNRJ12A8AE46E38
# 2    2.0         2.0  TRMMRUB12903CA097C  SOGDEWJ12AB0184C06
# 3    3.0         4.0  TRMMFIS128E078EDEA  SOYURIX12A6701E960
# 4    4.0         7.0  TRMMNZH128F92CF7D0  SOXCAWC12A8C144428
#
#                       artist                           title  year  peak  \
# 0                  AEROSMITH  REMEMBER (WALKING IN THE SAND)  1979   6.0
# 1  MICHAEL CERA , ELLEN PAGE             ANYONE ELSE BUT YOU  2007   2.0
# 2               BROOK BENTON                       LIE TO ME  1986  10.0
# 3                  AEROSMITH                          CRYIN'  1993  26.0
# 4               BUSTER BROWN                      SUGAR BABE  2002   2.0
#
#    weeks  Successful                     title_clean artist_feat  \
# 0   67.0           1  REMEMBER (WALKING IN THE SAND)        None
# 1   91.0           1             ANYONE ELSE BUT YOU        None
# 2   13.0           1                       LIE TO ME        None
# 3   12.0           1                          CRYIN'        None
# 4   99.0           1                      SUGAR BABE        None
#
#         artist_1     artist_2 artist_3
# 0      AEROSMITH         None     None
# 1  MICHAEL CERA    ELLEN PAGE     None
# 2   BROOK BENTON         None     None
# 3      AEROSMITH         None     None
# 4   BUSTER BROWN         None     None

# %%
# Find a duplicate rows
bb_filtered_df = bb_df.drop_duplicates(subset=['artist_1', 'artist_2', 'year', 'title_clean', 'artist_feat'])
bb_filtered_df.sort_values(by="year",ascending=False)
# Out:
#          index  Unnamed: 0              msd_id        echo_nest_id  \
# 65         NaN         NaN                 NaN                 NaN
# 281        NaN         NaN                 NaN                 NaN
# 36         NaN         NaN                 NaN                 NaN
# 288        NaN         NaN                 NaN                 NaN
# 287        NaN         NaN                 NaN                 NaN
# ...        ...         ...                 ...                 ...
# 65756  65755.0     65755.0  TRJLNHE128F426D6C3  SODIWMX12A58A79CCB
# 79861  79861.0     79861.0  TROOIKH12903CC6109  SOJGRZW12AB018C780
# 39615  39615.0     39615.0  TRAGJGZ128F421EE19  SODVIWU12A6D4FCDA6
# 46582  46582.0     46582.0  TRPWVXS128F4280DD3  SOKKDXY12A8C13A5D9
# 27829  27829.0     27829.0  TRFECYI12903CB4B31  SOIMCPE12AB017CB34
#
#                               artist  \
# 65                      RICH THE KID
# 281                KHALID , SWAE LEE
# 36     CARDI B, BAD BUNNY , J BALVIN
# 288            LIAM PAYNE , RITA ORA
# 287                      KEITH URBAN
# ...                              ...
# 65756           BLIND WILLIE JOHNSON
# 79861            BLIND WILLIE MCTELL
# 39615            BLIND WILLIE MCTELL
# 46582           PAPA CHARLIE JACKSON
# 27829   CLARENCE WILLIAMS' BLUE FIVE
#
#                                             title  year  peak  weeks  \
# 65                                      PLUG WALK  2018   NaN    NaN
# 281                                      THE WAYS  2018   NaN    NaN
# 36                                      I LIKE IT  2018   NaN    NaN
# 288                  FOR YOU (FIFTY SHADES FREED)  2018   NaN    NaN
# 287                                        FEMALE  2018   NaN    NaN
# ...                                           ...   ...   ...    ...
# 65756  IF I HAD MY WAY I'D TEAR THE BUILDING DOWN  1928   NaN    NaN
# 79861                            DARK NIGHT BLUES  1928   NaN    NaN
# 39615                         WRITING PAPER BLUES  1927   NaN    NaN
# 46582                             SKOODLE-UM-SKOO  1927   NaN    NaN
# 27829                        PICKIN' ON YOUR BABY  1925   NaN    NaN
#
#        Successful                                 title_clean artist_feat  \
# 65              1                                   PLUG WALK        None
# 281             1                                    THE WAYS        None
# 36              1                                   I LIKE IT        None
# 288             1                FOR YOU (FIFTY SHADES FREED)        None
# 287             1                                      FEMALE        None
# ...           ...                                         ...         ...
# 65756           0  IF I HAD MY WAY I'D TEAR THE BUILDING DOWN        None
# 79861           0                            DARK NIGHT BLUES        None
# 39615           0                         WRITING PAPER BLUES        None
# 46582           0                             SKOODLE-UM-SKOO        None
# 27829           0                        PICKIN' ON YOUR BABY        None
#
#                            artist_1     artist_2   artist_3
# 65                     RICH THE KID         None       None
# 281                         KHALID      SWAE LEE       None
# 36                          CARDI B   BAD BUNNY    J BALVIN
# 288                     LIAM PAYNE      RITA ORA       None
# 287                     KEITH URBAN         None       None
# ...                             ...          ...        ...
# 65756          BLIND WILLIE JOHNSON         None       None
# 79861           BLIND WILLIE MCTELL         None       None
# 39615           BLIND WILLIE MCTELL         None       None
# 46582          PAPA CHARLIE JACKSON         None       None
# 27829  CLARENCE WILLIAMS' BLUE FIVE         None       None
#
# [112882 rows x 15 columns]

# %%
# Drop the artist and title columns
bb_filtered_df = bb_filtered_df.drop(["artist","title"],axis=1)

# %%
bb_filtered_df.columns.get_loc("title_clean")
# Out:
# 8

# %%
bb_filtered_df.rename(columns={'artist_1' : 'artist',
                               'title_clean': 'title'},inplace=True)
bb_filtered_df.head()
# Out:
#    index  Unnamed: 0              msd_id        echo_nest_id  year  peak  \
# 0    0.0         0.0  TRMMWJS12903CBB7F5  SOLBDWO12AB0188CC2  1979   6.0
# 1    1.0         1.0  TRMMCDR128F423AB03  SOSZNRJ12A8AE46E38  2007   2.0
# 2    2.0         2.0  TRMMRUB12903CA097C  SOGDEWJ12AB0184C06  1986  10.0
# 3    3.0         4.0  TRMMFIS128E078EDEA  SOYURIX12A6701E960  1993  26.0
# 4    4.0         7.0  TRMMNZH128F92CF7D0  SOXCAWC12A8C144428  2002   2.0
#
#    weeks  Successful                           title artist_feat  \
# 0   67.0           1  REMEMBER (WALKING IN THE SAND)        None
# 1   91.0           1             ANYONE ELSE BUT YOU        None
# 2   13.0           1                       LIE TO ME        None
# 3   12.0           1                          CRYIN'        None
# 4   99.0           1                      SUGAR BABE        None
#
#           artist     artist_2 artist_3
# 0      AEROSMITH         None     None
# 1  MICHAEL CERA    ELLEN PAGE     None
# 2   BROOK BENTON         None     None
# 3      AEROSMITH         None     None
# 4   BUSTER BROWN         None     None

# %%
# Check the dataframe 
(bb_filtered_df["Successful"]).sum()
# Out:
# 23850

# %%
# Check the dataframe 
bb_filtered_df.shape
# Out:
# (112882, 13)

# %%
# Create two separate dataframes for Billboard and nonBillboard rows with the same structure 
non_bb_df = bb_filtered_df.loc[lambda x: x.msd_id.isnull() == True]
bb_only_df = bb_filtered_df.loc[lambda x: x.msd_id.isnull() == False]

# %%
# Get the df shape 
non_bb_df.shape
# Out:
# (18018, 13)

# %%
# Get the df shape 
bb_only_df.shape
# Out:
# (94864, 13)
