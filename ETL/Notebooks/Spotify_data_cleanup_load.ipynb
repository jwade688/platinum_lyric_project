# %%
# Import dependencies
import pandas as pd
import numpy as np
import psycopg2
from sqlalchemy import create_engine
import re
from config import db_pwd, RDS_pwd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# update Postgres Connection, at the end of notebook, before exporting : local or RDS

# %%
# Import Spotify dataset
spotify_df = pd.read_csv('../Resources/Spotify_Data_1921-2020.csv')
spotify_df.head()
# Out:
#    acousticness                                   artists  danceability  \
# 0         0.995                       ['Carl Woitschach']         0.708
# 1         0.994  ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2         0.604                   ['Seweryn Goszczyński']         0.749
# 3         0.995                      ['Francisco Canaro']         0.781
# 4         0.990  ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       158648  0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD             0.563
# 1       282133  0.0135         0  6KuQTIu1KoTTkLXKrwlLPV             0.901
# 2       104300  0.2200         0  6L63VW0PibdM1HDSBoqnoM             0.000
# 3       180760  0.1300         0  6M94FkXd15sOAOQYRnWPN8             0.887
# 4       687733  0.2040         0  6N6tiFZ9vLTSOIxkj8qKrd             0.908
#
#    key  liveness  loudness  mode  \
# 0   10    0.1510   -12.428     1
# 1    8    0.0763   -28.454     1
# 2    5    0.1190   -19.924     0
# 3    1    0.1110   -14.734     0
# 4   11    0.0980   -16.829     1
#
#                                             name  popularity release_date  \
# 0                    Singende Bataillone 1. Teil           0         1928
# 1       Fantasiestücke, Op. 111: Più tosto lento           0         1928
# 2                 Chapter 1.18 - Zamek kaniowski           0         1928
# 3  Bebamos Juntos - Instrumental (Remasterizado)           0   1928-09-25
# 4    Polonaise-Fantaisie in A-Flat Major, Op. 61           1         1928
#
#    speechiness    tempo  valence  year
# 0       0.0506  118.469   0.7790  1928
# 1       0.0462   83.972   0.0767  1928
# 2       0.9290  107.177   0.8800  1928
# 3       0.0926  108.003   0.7200  1928
# 4       0.0424   62.149   0.0693  1928

# %%
# Row count
len(spotify_df)
# Out:
# 169909

# %%
# # Test of artist formatting
# test = "['Robert Schumann', 'Vladimir Horowitz']"
# test_cleaner = test.replace("'", "").strip("[").strip("\]")
# test_cleaner

# %%
# Apply formatting to artists column
spotify_df['artists'] = spotify_df['artists'].str.replace("'", "").str.replace("[", "").str.replace("]", "")
spotify_df.head()
# Out:
#    acousticness                             artists  danceability  \
# 0         0.995                     Carl Woitschach         0.708
# 1         0.994  Robert Schumann, Vladimir Horowitz         0.379
# 2         0.604                 Seweryn Goszczyński         0.749
# 3         0.995                    Francisco Canaro         0.781
# 4         0.990  Frédéric Chopin, Vladimir Horowitz         0.210
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       158648  0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD             0.563
# 1       282133  0.0135         0  6KuQTIu1KoTTkLXKrwlLPV             0.901
# 2       104300  0.2200         0  6L63VW0PibdM1HDSBoqnoM             0.000
# 3       180760  0.1300         0  6M94FkXd15sOAOQYRnWPN8             0.887
# 4       687733  0.2040         0  6N6tiFZ9vLTSOIxkj8qKrd             0.908
#
#    key  liveness  loudness  mode  \
# 0   10    0.1510   -12.428     1
# 1    8    0.0763   -28.454     1
# 2    5    0.1190   -19.924     0
# 3    1    0.1110   -14.734     0
# 4   11    0.0980   -16.829     1
#
#                                             name  popularity release_date  \
# 0                    Singende Bataillone 1. Teil           0         1928
# 1       Fantasiestücke, Op. 111: Più tosto lento           0         1928
# 2                 Chapter 1.18 - Zamek kaniowski           0         1928
# 3  Bebamos Juntos - Instrumental (Remasterizado)           0   1928-09-25
# 4    Polonaise-Fantaisie in A-Flat Major, Op. 61           1         1928
#
#    speechiness    tempo  valence  year
# 0       0.0506  118.469   0.7790  1928
# 1       0.0462   83.972   0.0767  1928
# 2       0.9290  107.177   0.8800  1928
# 3       0.0926  108.003   0.7200  1928
# 4       0.0424   62.149   0.0693  1928

# %%
# Concatenate artist column by comma
spotify_df=pd.concat([spotify_df,spotify_df.artists.str.split(',',expand=True)],1)

# keep only the top 3 artists
spotify_df = spotify_df.drop(spotify_df.columns[22:59], axis=1)

#rename the columns
spotify_df = spotify_df.rename(columns={0: 'artist', 1: 'artist_2', 2: 'artist_3'})

# drop columns artists, artist_2, artist_3
spotify_df=spotify_df.drop(columns=["artists", "artist_2", "artist_3"], axis=1)

spotify_df.head()
# Out:
#    acousticness  danceability  duration_ms  energy  explicit  \
# 0         0.995         0.708       158648  0.1950         0
# 1         0.994         0.379       282133  0.0135         0
# 2         0.604         0.749       104300  0.2200         0
# 3         0.995         0.781       180760  0.1300         0
# 4         0.990         0.210       687733  0.2040         0
#
#                        id  instrumentalness  key  liveness  loudness  mode  \
# 0  6KbQ3uYMLKb5jDxLF7wYDD             0.563   10    0.1510   -12.428     1
# 1  6KuQTIu1KoTTkLXKrwlLPV             0.901    8    0.0763   -28.454     1
# 2  6L63VW0PibdM1HDSBoqnoM             0.000    5    0.1190   -19.924     0
# 3  6M94FkXd15sOAOQYRnWPN8             0.887    1    0.1110   -14.734     0
# 4  6N6tiFZ9vLTSOIxkj8qKrd             0.908   11    0.0980   -16.829     1
#
#                                             name  popularity release_date  \
# 0                    Singende Bataillone 1. Teil           0         1928
# 1       Fantasiestücke, Op. 111: Più tosto lento           0         1928
# 2                 Chapter 1.18 - Zamek kaniowski           0         1928
# 3  Bebamos Juntos - Instrumental (Remasterizado)           0   1928-09-25
# 4    Polonaise-Fantaisie in A-Flat Major, Op. 61           1         1928
#
#    speechiness    tempo  valence  year               artist
# 0       0.0506  118.469   0.7790  1928      Carl Woitschach
# 1       0.0462   83.972   0.0767  1928      Robert Schumann
# 2       0.9290  107.177   0.8800  1928  Seweryn Goszczyński
# 3       0.0926  108.003   0.7200  1928     Francisco Canaro
# 4       0.0424   62.149   0.0693  1928      Frédéric Chopin

# %%
# drop unnecessary column "release_date"
spotify_df=spotify_df.drop(columns=["release_date"], axis=1)

# %%
# Import Genre dataset
genre_df = pd.read_csv('../Resources/data_w_genres.csv')
genre_df = genre_df[['artists', 'genres']]
genre_df = genre_df.rename(columns={'artists': 'genre_artists'})
genre_df.head()
# Out:
#                                        genre_artists          genres
# 0                   "Cats" 1981 Original London Cast  ['show tunes']
# 1                          "Cats" 1983 Broadway Cast              []
# 2        "Fiddler On The Roof” Motion Picture Chorus              []
# 3     "Fiddler On The Roof” Motion Picture Orchestra              []
# 4  "Joseph And The Amazing Technicolor Dreamcoat"...              []

# %%
genre_df.shape
# Out:
# (27621, 2)

# %%
# Merge the genres to the spotify data
spotify_df = spotify_df.merge(genre_df[['genre_artists', 'genres']], 
                              left_on='artist', 
                              right_on='genre_artists', 
                              how='left').drop('genre_artists',axis=1)
spotify_df.head()
# Out:
#    acousticness  danceability  duration_ms  energy  explicit  \
# 0         0.995         0.708       158648  0.1950         0
# 1         0.994         0.379       282133  0.0135         0
# 2         0.604         0.749       104300  0.2200         0
# 3         0.995         0.781       180760  0.1300         0
# 4         0.990         0.210       687733  0.2040         0
#
#                        id  instrumentalness  key  liveness  loudness  mode  \
# 0  6KbQ3uYMLKb5jDxLF7wYDD             0.563   10    0.1510   -12.428     1
# 1  6KuQTIu1KoTTkLXKrwlLPV             0.901    8    0.0763   -28.454     1
# 2  6L63VW0PibdM1HDSBoqnoM             0.000    5    0.1190   -19.924     0
# 3  6M94FkXd15sOAOQYRnWPN8             0.887    1    0.1110   -14.734     0
# 4  6N6tiFZ9vLTSOIxkj8qKrd             0.908   11    0.0980   -16.829     1
#
#                                             name  popularity  speechiness  \
# 0                    Singende Bataillone 1. Teil           0       0.0506
# 1       Fantasiestücke, Op. 111: Più tosto lento           0       0.0462
# 2                 Chapter 1.18 - Zamek kaniowski           0       0.9290
# 3  Bebamos Juntos - Instrumental (Remasterizado)           0       0.0926
# 4    Polonaise-Fantaisie in A-Flat Major, Op. 61           1       0.0424
#
#      tempo  valence  year               artist  \
# 0  118.469   0.7790  1928      Carl Woitschach
# 1   83.972   0.0767  1928      Robert Schumann
# 2  107.177   0.8800  1928  Seweryn Goszczyński
# 3  108.003   0.7200  1928     Francisco Canaro
# 4   62.149   0.0693  1928      Frédéric Chopin
#
#                                               genres
# 0                                                 []
# 1                ['classical', 'early romantic era']
# 2                                                 []
# 3                         ['tango', 'vintage tango']
# 4  ['classical', 'early romantic era', 'polish cl...

# %%
# Reorder columns
spotify_df = spotify_df[['id', 
                         'artist',
                         'name',
                         'genres',
                         'popularity', 
                         'year',  
                         'duration_ms', 
                         'tempo', 
                         'key', 
                         'mode',
                         'acousticness', 
                         'instrumentalness', 
                         'danceability', 
                         'energy', 
                         'liveness',
                         'loudness',
                         'speechiness', 
                         'valence', 
                         'explicit'
                         ]]
spotify_df.head()
# Out:
#                        id               artist  \
# 0  6KbQ3uYMLKb5jDxLF7wYDD      Carl Woitschach
# 1  6KuQTIu1KoTTkLXKrwlLPV      Robert Schumann
# 2  6L63VW0PibdM1HDSBoqnoM  Seweryn Goszczyński
# 3  6M94FkXd15sOAOQYRnWPN8     Francisco Canaro
# 4  6N6tiFZ9vLTSOIxkj8qKrd      Frédéric Chopin
#
#                                             name  \
# 0                    Singende Bataillone 1. Teil
# 1       Fantasiestücke, Op. 111: Più tosto lento
# 2                 Chapter 1.18 - Zamek kaniowski
# 3  Bebamos Juntos - Instrumental (Remasterizado)
# 4    Polonaise-Fantaisie in A-Flat Major, Op. 61
#
#                                               genres  popularity  year  \
# 0                                                 []           0  1928
# 1                ['classical', 'early romantic era']           0  1928
# 2                                                 []           0  1928
# 3                         ['tango', 'vintage tango']           0  1928
# 4  ['classical', 'early romantic era', 'polish cl...           1  1928
#
#    duration_ms    tempo  key  mode  acousticness  instrumentalness  \
# 0       158648  118.469   10     1         0.995             0.563
# 1       282133   83.972    8     1         0.994             0.901
# 2       104300  107.177    5     0         0.604             0.000
# 3       180760  108.003    1     0         0.995             0.887
# 4       687733   62.149   11     1         0.990             0.908
#
#    danceability  energy  liveness  loudness  speechiness  valence  explicit
# 0         0.708  0.1950    0.1510   -12.428       0.0506   0.7790         0
# 1         0.379  0.0135    0.0763   -28.454       0.0462   0.0767         0
# 2         0.749  0.2200    0.1190   -19.924       0.9290   0.8800         0
# 3         0.781  0.1300    0.1110   -14.734       0.0926   0.7200         0
# 4         0.210  0.2040    0.0980   -16.829       0.0424   0.0693         0

# %%
# Apply formatting to genre column
spotify_df['genres'] = spotify_df['genres'].str.replace("'", "").str.replace("[", "").str.replace("]", "")
spotify_df.head()
# Out:
#                        id               artist  \
# 0  6KbQ3uYMLKb5jDxLF7wYDD      Carl Woitschach
# 1  6KuQTIu1KoTTkLXKrwlLPV      Robert Schumann
# 2  6L63VW0PibdM1HDSBoqnoM  Seweryn Goszczyński
# 3  6M94FkXd15sOAOQYRnWPN8     Francisco Canaro
# 4  6N6tiFZ9vLTSOIxkj8qKrd      Frédéric Chopin
#
#                                             name  \
# 0                    Singende Bataillone 1. Teil
# 1       Fantasiestücke, Op. 111: Più tosto lento
# 2                 Chapter 1.18 - Zamek kaniowski
# 3  Bebamos Juntos - Instrumental (Remasterizado)
# 4    Polonaise-Fantaisie in A-Flat Major, Op. 61
#
#                                             genres  popularity  year  \
# 0                                                            0  1928
# 1                    classical, early romantic era           0  1928
# 2                                                            0  1928
# 3                             tango, vintage tango           0  1928
# 4  classical, early romantic era, polish classical           1  1928
#
#    duration_ms    tempo  key  mode  acousticness  instrumentalness  \
# 0       158648  118.469   10     1         0.995             0.563
# 1       282133   83.972    8     1         0.994             0.901
# 2       104300  107.177    5     0         0.604             0.000
# 3       180760  108.003    1     0         0.995             0.887
# 4       687733   62.149   11     1         0.990             0.908
#
#    danceability  energy  liveness  loudness  speechiness  valence  explicit
# 0         0.708  0.1950    0.1510   -12.428       0.0506   0.7790         0
# 1         0.379  0.0135    0.0763   -28.454       0.0462   0.0767         0
# 2         0.749  0.2200    0.1190   -19.924       0.9290   0.8800         0
# 3         0.781  0.1300    0.1110   -14.734       0.0926   0.7200         0
# 4         0.210  0.2040    0.0980   -16.829       0.0424   0.0693         0

# %%
#test = spotify_df[~spotify_df['genres'].str.contains('classical', na=False)]
# https://stackoverflow.com/questions/52297740/typeerror-bad-operand-type-for-unary-float/52297788

# %%
# Replace blank values in genre column with NaN
spotify_df['genres'].replace('', np.nan, inplace=True)
# https://stackoverflow.com/questions/29314033/drop-rows-containing-empty-cells-from-a-pandas-dataframe

# Drop the rows when genre = NaN
spotify_df = spotify_df.dropna(subset=['genres'])

spotify_df.head()
# Out:
#                        id             artist  \
# 1  6KuQTIu1KoTTkLXKrwlLPV    Robert Schumann
# 3  6M94FkXd15sOAOQYRnWPN8   Francisco Canaro
# 4  6N6tiFZ9vLTSOIxkj8qKrd    Frédéric Chopin
# 5  6NxAf7M8DNHOBTmEd3JSO5  Felix Mendelssohn
# 6  6O0puPuyrxPjDTHDUgsWI7        Franz Liszt
#
#                                              name  \
# 1        Fantasiestücke, Op. 111: Più tosto lento
# 3   Bebamos Juntos - Instrumental (Remasterizado)
# 4     Polonaise-Fantaisie in A-Flat Major, Op. 61
# 5                     Scherzo a capriccio: Presto
# 6  Valse oubliée No. 1 in F-Sharp Major, S. 215/1
#
#                                             genres  popularity  year  \
# 1                    classical, early romantic era           0  1928
# 3                             tango, vintage tango           0  1928
# 4  classical, early romantic era, polish classical           1  1928
# 5                    classical, early romantic era           0  1928
# 6                     classical, late romantic era           0  1928
#
#    duration_ms    tempo  key  mode  acousticness  instrumentalness  \
# 1       282133   83.972    8     1         0.994             0.901
# 3       180760  108.003    1     0         0.995             0.887
# 4       687733   62.149   11     1         0.990             0.908
# 5       352600   63.521    6     0         0.995             0.911
# 6       136627   80.495   11     1         0.956             0.435
#
#    danceability  energy  liveness  loudness  speechiness  valence  explicit
# 1         0.379  0.0135    0.0763   -28.454       0.0462   0.0767         0
# 3         0.781  0.1300    0.1110   -14.734       0.0926   0.7200         0
# 4         0.210  0.2040    0.0980   -16.829       0.0424   0.0693         0
# 5         0.424  0.1200    0.0915   -19.242       0.0593   0.2660         0
# 6         0.444  0.1970    0.0744   -17.226       0.0400   0.3050         0

# %%
spotify_df.shape
# Out:
# (151765, 19)

# %%
# Create a list of genres keywords to keep
keep_list = ['rap','rock', 'pop', 'country', 'blues', 'jazz', 'punk', 'metal', 'folk', 'jam', 'electronic', 'edm', 'reggae', 'rhythm and blues']

# Create a new df to fill
spotify_filtered_df = spotify_df[spotify_df['genres'].str.contains("hip hop", na=False)]

# Loop through the genre list and add those rows to the 
for genre in keep_list:
    test2 = spotify_df[spotify_df['genres'].str.contains(genre, na=False)]
    spotify_filtered_df = spotify_filtered_df.append(test2)

### IS THERE A WAY TO APPEND ROWS ONLY IF UNIQUE SO THE DROP DUPLICATES IS NOT NEEDED??
    
# Drop duplicate rows 
spotify_filtered_df = spotify_filtered_df.drop_duplicates(subset=['artist', 'name'])

# Sort by ID
spotify_filtered_df = spotify_filtered_df.sort_values(by=['id'])
spotify_filtered_df.head()
# Out:
#                             id             artist  \
# 165680  000G1xMMuwxNHmwVsBdtj1            Blondie
# 9542    000ZxLGm7jDlWCHtcXSeBe  Meade "Lux" Lewis
# 123062  000u1dTg7y1XCDXi80hbBX              Texas
# 139777  000x2qE0ZI3hodeVrnJK8A              Heart
# 77749   000xQL6tZNLJzIrtIgxqSl               ZAYN
#
#                                           name  \
# 165680                    Will Anything Happen
# 9542                             Torpedo Juice
# 123062                    I Don't Want A Lover
# 139777  (Love Me Like Music) I'll Be Your Song
# 77749     Still Got Time (feat. PARTYNEXTDOOR)
#
#                                                    genres  popularity  year  \
# 165680  candy pop, dance rock, new romantic, new wave,...          27  1978
# 9542          boogie-woogie, piano blues, ragtime, stride           1  1954
# 123062                country, country road, country rock          61  1989
# 139777  album rock, classic rock, country rock, folk r...          34  1975
# 77749   dance pop, electropop, pop, post-teen pop, uk pop          64  2017
#
#         duration_ms    tempo  key  mode  acousticness  instrumentalness  \
# 165680       182347  191.307    2     1        0.0131          0.000106
# 9542         314667   97.694    2     0        0.7950          0.878000
# 123062       300600  120.484    7     1        0.1960          0.000487
# 139777       200627  134.248    0     1        0.3390          0.000000
# 77749        188491  120.963    7     1        0.1310          0.000000
#
#         danceability  energy  liveness  loudness  speechiness  valence  \
# 165680         0.256   0.895    0.0821    -4.860       0.0707    0.555
# 9542           0.685   0.483    0.1130   -10.202       0.0337    0.854
# 123062         0.756   0.470    0.1260   -12.615       0.0394    0.430
# 139777         0.507   0.356    0.1800   -14.240       0.0306    0.472
# 77749          0.748   0.627    0.0852    -6.029       0.0644    0.524
#
#         explicit
# 165680         0
# 9542           0
# 123062         0
# 139777         0
# 77749          0

# %%
len(spotify_filtered_df)
# Out:
# 102356

# %%
# lower case artist and title columns
spotify_filtered_df['artist'] = spotify_filtered_df['artist'].str.lower()
spotify_filtered_df['name'] = spotify_filtered_df['name'].str.lower()
spotify_filtered_df.head()
# Out:
#                             id             artist  \
# 165680  000G1xMMuwxNHmwVsBdtj1            blondie
# 9542    000ZxLGm7jDlWCHtcXSeBe  meade "lux" lewis
# 123062  000u1dTg7y1XCDXi80hbBX              texas
# 139777  000x2qE0ZI3hodeVrnJK8A              heart
# 77749   000xQL6tZNLJzIrtIgxqSl               zayn
#
#                                           name  \
# 165680                    will anything happen
# 9542                             torpedo juice
# 123062                    i don't want a lover
# 139777  (love me like music) i'll be your song
# 77749     still got time (feat. partynextdoor)
#
#                                                    genres  popularity  year  \
# 165680  candy pop, dance rock, new romantic, new wave,...          27  1978
# 9542          boogie-woogie, piano blues, ragtime, stride           1  1954
# 123062                country, country road, country rock          61  1989
# 139777  album rock, classic rock, country rock, folk r...          34  1975
# 77749   dance pop, electropop, pop, post-teen pop, uk pop          64  2017
#
#         duration_ms    tempo  key  mode  acousticness  instrumentalness  \
# 165680       182347  191.307    2     1        0.0131          0.000106
# 9542         314667   97.694    2     0        0.7950          0.878000
# 123062       300600  120.484    7     1        0.1960          0.000487
# 139777       200627  134.248    0     1        0.3390          0.000000
# 77749        188491  120.963    7     1        0.1310          0.000000
#
#         danceability  energy  liveness  loudness  speechiness  valence  \
# 165680         0.256   0.895    0.0821    -4.860       0.0707    0.555
# 9542           0.685   0.483    0.1130   -10.202       0.0337    0.854
# 123062         0.756   0.470    0.1260   -12.615       0.0394    0.430
# 139777         0.507   0.356    0.1800   -14.240       0.0306    0.472
# 77749          0.748   0.627    0.0852    -6.029       0.0644    0.524
#
#         explicit
# 165680         0
# 9542           0
# 123062         0
# 139777         0
# 77749          0

# %%
# Test of song formatting - to remove all (), [] and everything inside (letters, numbers, space, .)
test = [{"name":"(hello hello) title of the song - version (extra. & % stuff) [other thing]", "artist" : "artist1"},
        {"name":"(hi) title of the another song [extra stuff] (other thing)", "artist" : "artist2"}]
test_df = pd.DataFrame(test)
test_df
# Out:
#                                                 name   artist
# 0  (hello hello) title of the song - version (ext...  artist1
# 1  (hi) title of the another song [extra stuff] (...  artist2

# %%
#test_df["name"] = test_df["name"].str.replace(r'\([\w\s]+\)', '', regex=True)
#test_df["name"] = test_df["name"].str.replace(r'\[[\w\s]+\]', '', regex=True)
#test_df["name"] = test_df["name"].str.replace(r'^\s+', '', regex=True)
#test_df["name"] = test_df["name"].str.replace(r'\s+$', '', regex=True)
test_df["name"] = test_df["name"].str.replace(r'\([^\(\)]+\)', '', regex=True)
test_df["name"] = test_df["name"].str.replace(r'\[[^\[\]]+\]', '', regex=True)
test_df["name"] = test_df["name"].str.replace(r'\s-.+', '', regex=True) 
test_df["name"] = test_df["name"].str.replace(r'^\s+', '', regex=True)
test_df["name"] = test_df["name"].str.replace(r'\s+$', '', regex=True)


test_df
# Out:
#                         name   artist
# 0          title of the song  artist1
# 1  title of the another song  artist2

# %%
# Create regex to find "Featuring" artists
feat_string = r'\s[f][e][a][t][u][r][e][s].+$|\s[f][e][a][t][u][r][i][n][g].+$|\s[f][e][a][t]\..+$'

# %%
# Apply formatting/removing to title column 
spotify_filtered_df['name'] = spotify_filtered_df['name'].str.replace(r'\([^\(\)]+\)', '', regex=True) #(...)
spotify_filtered_df['name'] = spotify_filtered_df['name'].str.replace(r'\[[^\[\]]+\]', '', regex=True) #[...] 
spotify_filtered_df['name'] = spotify_filtered_df['name'].str.replace(r'\s-.+', '', regex=True) # -...
spotify_filtered_df['name'] = spotify_filtered_df['name'].str.replace(r'\s&.+', '', regex=True)  # &...
spotify_filtered_df['name'] = spotify_filtered_df['name'].str.replace(feat_string, '', regex=True) # feat...
spotify_filtered_df['name'] = spotify_filtered_df['name'].str.replace(r'\/.+', '', regex=True) # /...
spotify_filtered_df['name'] = spotify_filtered_df['name'].str.replace(r'\\.+', '', regex=True) # \...
spotify_filtered_df['name'] = spotify_filtered_df['name'].str.replace(r';.+', '',  regex=True) # ;...
spotify_filtered_df['name'] = spotify_filtered_df['name'].str.replace(r'_.+', '',  regex=True) # _...
spotify_filtered_df['name'] = spotify_filtered_df['name'].str.replace(r'\s\s+', ' ',  regex=True ) # more than one blank space into one
spotify_filtered_df['name'] = spotify_filtered_df['name'].str.replace(r'^\s+', '', regex=True) # blank spaces at begiining
spotify_filtered_df['name'] = spotify_filtered_df['name'].str.replace(r'\s+$', '', regex=True) # blank spaces at end


spotify_filtered_df.head()
# Out:
#                             id             artist                  name  \
# 165680  000G1xMMuwxNHmwVsBdtj1            blondie  will anything happen
# 9542    000ZxLGm7jDlWCHtcXSeBe  meade "lux" lewis         torpedo juice
# 123062  000u1dTg7y1XCDXi80hbBX              texas  i don't want a lover
# 139777  000x2qE0ZI3hodeVrnJK8A              heart     i'll be your song
# 77749   000xQL6tZNLJzIrtIgxqSl               zayn        still got time
#
#                                                    genres  popularity  year  \
# 165680  candy pop, dance rock, new romantic, new wave,...          27  1978
# 9542          boogie-woogie, piano blues, ragtime, stride           1  1954
# 123062                country, country road, country rock          61  1989
# 139777  album rock, classic rock, country rock, folk r...          34  1975
# 77749   dance pop, electropop, pop, post-teen pop, uk pop          64  2017
#
#         duration_ms    tempo  key  mode  acousticness  instrumentalness  \
# 165680       182347  191.307    2     1        0.0131          0.000106
# 9542         314667   97.694    2     0        0.7950          0.878000
# 123062       300600  120.484    7     1        0.1960          0.000487
# 139777       200627  134.248    0     1        0.3390          0.000000
# 77749        188491  120.963    7     1        0.1310          0.000000
#
#         danceability  energy  liveness  loudness  speechiness  valence  \
# 165680         0.256   0.895    0.0821    -4.860       0.0707    0.555
# 9542           0.685   0.483    0.1130   -10.202       0.0337    0.854
# 123062         0.756   0.470    0.1260   -12.615       0.0394    0.430
# 139777         0.507   0.356    0.1800   -14.240       0.0306    0.472
# 77749          0.748   0.627    0.0852    -6.029       0.0644    0.524
#
#         explicit
# 165680         0
# 9542           0
# 123062         0
# 139777         0
# 77749          0

# %%
# Apply same formatting/removing to artist column 
spotify_filtered_df['artist'] = spotify_filtered_df['artist'].str.replace(r'\([^\(\)]+\)', '', regex=True)
spotify_filtered_df['artist'] = spotify_filtered_df['artist'].str.replace(r'\[[^\[\]]+\]', '', regex=True)
spotify_filtered_df['artist'] = spotify_filtered_df['artist'].str.replace(r'\s-.+', '', regex=True) 
spotify_filtered_df['artist'] = spotify_filtered_df['artist'].str.replace(r'\s&.+', '', regex=True)
spotify_filtered_df['artist'] = spotify_filtered_df['artist'].str.replace(feat_string, '', regex=True)
spotify_filtered_df['artist'] = spotify_filtered_df['artist'].str.replace(r'\/.+', '', regex=True) 
spotify_filtered_df['artist'] = spotify_filtered_df['artist'].str.replace(r'\\.+', '', regex=True) 
spotify_filtered_df['artist'] = spotify_filtered_df['artist'].str.replace(r';.+', '',  regex=True)
spotify_filtered_df['artist'] = spotify_filtered_df['artist'].str.replace(r'_.+', '',  regex=True) 
spotify_filtered_df['artist'] = spotify_filtered_df['artist'].str.replace(r'\s\s+', ' ',  regex=True )
spotify_filtered_df['artist'] = spotify_filtered_df['artist'].str.replace(r'^\s+', '', regex=True)
spotify_filtered_df['artist'] = spotify_filtered_df['artist'].str.replace(r'\s+$', '', regex=True)
spotify_filtered_df['artist'] = spotify_filtered_df['artist'].str.replace(r'"', '', regex=True) # remove "" in artist name

# %%
# Remove rows with non-ascii characters
# https://stackoverflow.com/questions/46094325/python-removing-non-ascii-characters-from-csv-file-using-pandas
spotify_filtered_df = spotify_filtered_df[~spotify_filtered_df['artist'].str.contains(r'[^\x00-\x7F]+')]
spotify_filtered_df = spotify_filtered_df[~spotify_filtered_df['name'].str.contains(r'[^\x00-\x7F]+')]
spotify_filtered_df.head()
# Out:
#                             id           artist                  name  \
# 165680  000G1xMMuwxNHmwVsBdtj1          blondie  will anything happen
# 9542    000ZxLGm7jDlWCHtcXSeBe  meade lux lewis         torpedo juice
# 123062  000u1dTg7y1XCDXi80hbBX            texas  i don't want a lover
# 139777  000x2qE0ZI3hodeVrnJK8A            heart     i'll be your song
# 77749   000xQL6tZNLJzIrtIgxqSl             zayn        still got time
#
#                                                    genres  popularity  year  \
# 165680  candy pop, dance rock, new romantic, new wave,...          27  1978
# 9542          boogie-woogie, piano blues, ragtime, stride           1  1954
# 123062                country, country road, country rock          61  1989
# 139777  album rock, classic rock, country rock, folk r...          34  1975
# 77749   dance pop, electropop, pop, post-teen pop, uk pop          64  2017
#
#         duration_ms    tempo  key  mode  acousticness  instrumentalness  \
# 165680       182347  191.307    2     1        0.0131          0.000106
# 9542         314667   97.694    2     0        0.7950          0.878000
# 123062       300600  120.484    7     1        0.1960          0.000487
# 139777       200627  134.248    0     1        0.3390          0.000000
# 77749        188491  120.963    7     1        0.1310          0.000000
#
#         danceability  energy  liveness  loudness  speechiness  valence  \
# 165680         0.256   0.895    0.0821    -4.860       0.0707    0.555
# 9542           0.685   0.483    0.1130   -10.202       0.0337    0.854
# 123062         0.756   0.470    0.1260   -12.615       0.0394    0.430
# 139777         0.507   0.356    0.1800   -14.240       0.0306    0.472
# 77749          0.748   0.627    0.0852    -6.029       0.0644    0.524
#
#         explicit
# 165680         0
# 9542           0
# 123062         0
# 139777         0
# 77749          0

# %%
len(spotify_filtered_df)
# Out:
# 97754

# %%
new_column_names = {
    "id": "spot_id",
    "artist": "artist_name",
    "name": "song_title",
    "genres": "features_genres",
    "popularity": "feature_popularity",
    "year": "song_year",
    "duration_ms": "feature_duration",
    "tempo": "feature_tempo",
    "key": "feature_key",
    "mode": "feature_mode",
    "acousticness": "feature_acousticness",
    "instrumentalness": "feature_instrumentalness",
    "danceability": "feature_danceability",
    "energy": "feature_energy",
    "liveness": "feature_liveness",
    "loudness": "feature_loudness",
    "speechiness": "feature_speechiness",
    "valence": "feature_valence",
    "explicit": "feature_explicit"
}

# %%
spotify_filtered_df = spotify_filtered_df.rename(columns = new_column_names)
spotify_filtered_df.head()
# Out:
#                        spot_id      artist_name            song_title  \
# 165680  000G1xMMuwxNHmwVsBdtj1          blondie  will anything happen
# 9542    000ZxLGm7jDlWCHtcXSeBe  meade lux lewis         torpedo juice
# 123062  000u1dTg7y1XCDXi80hbBX            texas  i don't want a lover
# 139777  000x2qE0ZI3hodeVrnJK8A            heart     i'll be your song
# 77749   000xQL6tZNLJzIrtIgxqSl             zayn        still got time
#
#                                           features_genres  feature_popularity  \
# 165680  candy pop, dance rock, new romantic, new wave,...                  27
# 9542          boogie-woogie, piano blues, ragtime, stride                   1
# 123062                country, country road, country rock                  61
# 139777  album rock, classic rock, country rock, folk r...                  34
# 77749   dance pop, electropop, pop, post-teen pop, uk pop                  64
#
#         song_year  feature_duration  feature_tempo  feature_key  feature_mode  \
# 165680       1978            182347        191.307            2             1
# 9542         1954            314667         97.694            2             0
# 123062       1989            300600        120.484            7             1
# 139777       1975            200627        134.248            0             1
# 77749        2017            188491        120.963            7             1
#
#         feature_acousticness  feature_instrumentalness  feature_danceability  \
# 165680                0.0131                  0.000106                 0.256
# 9542                  0.7950                  0.878000                 0.685
# 123062                0.1960                  0.000487                 0.756
# 139777                0.3390                  0.000000                 0.507
# 77749                 0.1310                  0.000000                 0.748
#
#         feature_energy  feature_liveness  feature_loudness  \
# 165680           0.895            0.0821            -4.860
# 9542             0.483            0.1130           -10.202
# 123062           0.470            0.1260           -12.615
# 139777           0.356            0.1800           -14.240
# 77749            0.627            0.0852            -6.029
#
#         feature_speechiness  feature_valence  feature_explicit
# 165680               0.0707            0.555                 0
# 9542                 0.0337            0.854                 0
# 123062               0.0394            0.430                 0
# 139777               0.0306            0.472                 0
# 77749                0.0644            0.524                 0

# %%
# extract the "features_genres" column into a DF, and drop it from spotify_filtered_df
genres_df = spotify_filtered_df[["spot_id", "features_genres"]]
spotify_filtered_df = spotify_filtered_df.drop(columns=["features_genres"], axis=1)
genres_df = genres_df.reset_index(drop=True)
genres_df.head()
# Out:
#                   spot_id                                    features_genres
# 0  000G1xMMuwxNHmwVsBdtj1  candy pop, dance rock, new romantic, new wave,...
# 1  000ZxLGm7jDlWCHtcXSeBe        boogie-woogie, piano blues, ragtime, stride
# 2  000u1dTg7y1XCDXi80hbBX                country, country road, country rock
# 3  000x2qE0ZI3hodeVrnJK8A  album rock, classic rock, country rock, folk r...
# 4  000xQL6tZNLJzIrtIgxqSl  dance pop, electropop, pop, post-teen pop, uk pop

# %%
# getting the main genre (from the genre_list) out of "genres" column into new column "genre_1"

genre_list = ['rap','rock', 'pop', 'country', 'blues', 'hip hop', 'jazz', 'punk', 'metal', 
              'folk', 'jam', 'electronic', 'edm', 'reggae', 'rhythm and blues', 'rnb', 'latin', 'world']

for i in range(len(genres_df)) : 
    
    dico={}
    
    for genre in genre_list:
        if genres_df.loc[i, "features_genres"].find(genre) !=-1:
            dico[genre]= genres_df.loc[i, "features_genres"].find(genre)
                    
    if len(dico)==1:
        genres_df.loc[i, "genre_1"]= list(dico.keys())[0]
            
    elif len(dico)>1:
        j = 1
        first = 0
        while j <(len(dico)):
            if list(dico.values())[j]<list(dico.values())[j-1]:
                first = j
            j=j+1
        genres_df.loc[i, "genre_1"]= list(dico.keys())[first]    
        
        
genres_df.head(10)
# Out:
#                   spot_id                                    features_genres  \
# 0  000G1xMMuwxNHmwVsBdtj1  candy pop, dance rock, new romantic, new wave,...
# 1  000ZxLGm7jDlWCHtcXSeBe        boogie-woogie, piano blues, ragtime, stride
# 2  000u1dTg7y1XCDXi80hbBX                country, country road, country rock
# 3  000x2qE0ZI3hodeVrnJK8A  album rock, classic rock, country rock, folk r...
# 4  000xQL6tZNLJzIrtIgxqSl  dance pop, electropop, pop, post-teen pop, uk pop
# 5  001UkMQHw4zXfFNdKpwXAF        contemporary country, country, country road
# 6  0024tEymsoc9FyKUauQngQ                                 cyberpunk, new age
# 7  002CcxKpBE1tfKOy2CRaWr  chutney, classic bollywood, desi pop, filmi, g...
# 8  002aR3zqP6SvscCnPT44on                             jazz funk, smooth jazz
# 9  002zOHMdBKYgNGtmmHSE2D    adult standards, lounge, torch song, vocal jazz
#
#    genre_1
# 0      pop
# 1    blues
# 2  country
# 3  country
# 4      pop
# 5  country
# 6     punk
# 7      pop
# 8     jazz
# 9     jazz

# %%
genres_df.genre_1.value_counts()
# Out:
# rock                21964
# pop                 20716
# jazz                12864
# country              8818
# hip hop              6221
# folk                 5872
# metal                5128
# blues                5011
# rap                  3023
# punk                 2440
# latin                2435
# reggae               1208
# rhythm and blues      674
# electronic            546
# edm                   539
# jam                   233
# world                  62
# Name: genre_1, dtype: int64

# %%
genres_df["genre_1"].isnull().sum()
# Out:
# 0

# %%
# add the "genre_1" column to spotify_filtered_df, and rename "genre_1"

spotify_filtered_df = spotify_filtered_df.merge(genres_df[["spot_id","genre_1"]], left_on="spot_id", right_on="spot_id")
#spotify_filtered_df = spotify_filtered_df.drop("features_genres", axis=1)
spotify_filtered_df = spotify_filtered_df.rename(columns={"genre_1": "feature_genre"})

spotify_filtered_df.head()
# Out:
#                   spot_id      artist_name            song_title  \
# 0  000G1xMMuwxNHmwVsBdtj1          blondie  will anything happen
# 1  000ZxLGm7jDlWCHtcXSeBe  meade lux lewis         torpedo juice
# 2  000u1dTg7y1XCDXi80hbBX            texas  i don't want a lover
# 3  000x2qE0ZI3hodeVrnJK8A            heart     i'll be your song
# 4  000xQL6tZNLJzIrtIgxqSl             zayn        still got time
#
#    feature_popularity  song_year  feature_duration  feature_tempo  \
# 0                  27       1978            182347        191.307
# 1                   1       1954            314667         97.694
# 2                  61       1989            300600        120.484
# 3                  34       1975            200627        134.248
# 4                  64       2017            188491        120.963
#
#    feature_key  feature_mode  feature_acousticness  feature_instrumentalness  \
# 0            2             1                0.0131                  0.000106
# 1            2             0                0.7950                  0.878000
# 2            7             1                0.1960                  0.000487
# 3            0             1                0.3390                  0.000000
# 4            7             1                0.1310                  0.000000
#
#    feature_danceability  feature_energy  feature_liveness  feature_loudness  \
# 0                 0.256           0.895            0.0821            -4.860
# 1                 0.685           0.483            0.1130           -10.202
# 2                 0.756           0.470            0.1260           -12.615
# 3                 0.507           0.356            0.1800           -14.240
# 4                 0.748           0.627            0.0852            -6.029
#
#    feature_speechiness  feature_valence  feature_explicit feature_genre
# 0               0.0707            0.555                 0           pop
# 1               0.0337            0.854                 0         blues
# 2               0.0394            0.430                 0       country
# 3               0.0306            0.472                 0       country
# 4               0.0644            0.524                 0           pop

# %%
spotify_filtered_df.shape
# Out:
# (97754, 19)

# %%
# reorder columns
spotify_filtered_df = spotify_filtered_df[[
    "spot_id",
    "artist_name",
    "song_title",
    "song_year",
    "feature_genre",
    "feature_popularity",
    "feature_duration",
    "feature_key",
    "feature_acousticness",
    "feature_instrumentalness",
    "feature_tempo",
    "feature_mode",
    "feature_danceability",
    "feature_energy",
    "feature_liveness",
    "feature_loudness",
    "feature_speechiness",
    "feature_valence",
    "feature_explicit"   
]]
spotify_filtered_df.head()
# Out:
#                   spot_id      artist_name            song_title  song_year  \
# 0  000G1xMMuwxNHmwVsBdtj1          blondie  will anything happen       1978
# 1  000ZxLGm7jDlWCHtcXSeBe  meade lux lewis         torpedo juice       1954
# 2  000u1dTg7y1XCDXi80hbBX            texas  i don't want a lover       1989
# 3  000x2qE0ZI3hodeVrnJK8A            heart     i'll be your song       1975
# 4  000xQL6tZNLJzIrtIgxqSl             zayn        still got time       2017
#
#   feature_genre  feature_popularity  feature_duration  feature_key  \
# 0           pop                  27            182347            2
# 1         blues                   1            314667            2
# 2       country                  61            300600            7
# 3       country                  34            200627            0
# 4           pop                  64            188491            7
#
#    feature_acousticness  feature_instrumentalness  feature_tempo  \
# 0                0.0131                  0.000106        191.307
# 1                0.7950                  0.878000         97.694
# 2                0.1960                  0.000487        120.484
# 3                0.3390                  0.000000        134.248
# 4                0.1310                  0.000000        120.963
#
#    feature_mode  feature_danceability  feature_energy  feature_liveness  \
# 0             1                 0.256           0.895            0.0821
# 1             0                 0.685           0.483            0.1130
# 2             1                 0.756           0.470            0.1260
# 3             1                 0.507           0.356            0.1800
# 4             1                 0.748           0.627            0.0852
#
#    feature_loudness  feature_speechiness  feature_valence  feature_explicit
# 0            -4.860               0.0707            0.555                 0
# 1           -10.202               0.0337            0.854                 0
# 2           -12.615               0.0394            0.430                 0
# 3           -14.240               0.0306            0.472                 0
# 4            -6.029               0.0644            0.524                 0

# %% [markdown]
# ## export to Postgres - create table "spotify" in Postgres first

# %%
# Connect to local database:
#db_string = f"postgres://postgres:{db_pwd}@127.0.0.1:5432/Platinum_Lyrics"

# Connect to RDS Database:
db_string = f"postgres://postgres:{RDS_pwd}@platinum-rds.cbu3an3ywyth.us-east-2.rds.amazonaws.com/Platinum_Lyrics"

engine = create_engine(db_string)

# %%
for ind in range(5,97):
    spotify_filtered_df[ind*1000:ind*1000+1000].to_sql(name='spotify', con=engine, index=False, 
          if_exists='append')
    print(f"Chunk {ind*1000}-{ind*1000+1000} exported")
    print("---------------------")

spotify_filtered_df[97000:97755].to_sql(name='spotify', con=engine, index=False, if_exists='append') 
print(f"Chunk 97000-97755 exported")

print("Export Successful")
# Out:
# Chunk 5000-6000 exported
# ---------------------
# Chunk 6000-7000 exported
# ---------------------
# Chunk 7000-8000 exported
# ---------------------
# Chunk 8000-9000 exported
# ---------------------
# Chunk 9000-10000 exported
# ---------------------
# Chunk 10000-11000 exported
# ---------------------
# Chunk 11000-12000 exported
# ---------------------
# Chunk 12000-13000 exported
# ---------------------
# Chunk 13000-14000 exported
# ---------------------
# Chunk 14000-15000 exported
# ---------------------
# Chunk 15000-16000 exported
# ---------------------
# Chunk 16000-17000 exported
# ---------------------
# Chunk 17000-18000 exported
# ---------------------
# Chunk 18000-19000 exported
# ---------------------
# Chunk 19000-20000 exported
# ---------------------
# Chunk 20000-21000 exported
# ---------------------
# Chunk 21000-22000 exported
# ---------------------
# Chunk 22000-23000 exported
# ---------------------
# Chunk 23000-24000 exported
# ---------------------
# Chunk 24000-25000 exported
# ---------------------
# Chunk 25000-26000 exported
# ---------------------
# Chunk 26000-27000 exported
# ---------------------
# Chunk 27000-28000 exported
# ---------------------
# Chunk 28000-29000 exported
# ---------------------
# Chunk 29000-30000 exported
# ---------------------
# Chunk 30000-31000 exported
# ---------------------
# Chunk 31000-32000 exported
# ---------------------
# Chunk 32000-33000 exported
# ---------------------
# Chunk 33000-34000 exported
# ---------------------
# Chunk 34000-35000 exported
# ---------------------
# Chunk 35000-36000 exported
# ---------------------
# Chunk 36000-37000 exported
# ---------------------
# Chunk 37000-38000 exported
# ---------------------
# Chunk 38000-39000 exported
# ---------------------
# Chunk 39000-40000 exported
# ---------------------
# Chunk 40000-41000 exported
# ---------------------
# Chunk 41000-42000 exported
# ---------------------
# Chunk 42000-43000 exported
# ---------------------
# Chunk 43000-44000 exported
# ---------------------
# Chunk 44000-45000 exported
# ---------------------
# Chunk 45000-46000 exported
# ---------------------
# Chunk 46000-47000 exported
# ---------------------
# Chunk 47000-48000 exported
# ---------------------
# Chunk 48000-49000 exported
# ---------------------
# Chunk 49000-50000 exported
# ---------------------
# Chunk 50000-51000 exported
# ---------------------
# Chunk 51000-52000 exported
# ---------------------
# Chunk 52000-53000 exported
# ---------------------
# Chunk 53000-54000 exported
# ---------------------
# Chunk 54000-55000 exported
# ---------------------
# Chunk 55000-56000 exported
# ---------------------
# Chunk 56000-57000 exported
# ---------------------
# Chunk 57000-58000 exported
# ---------------------
# Chunk 58000-59000 exported
# ---------------------
# Chunk 59000-60000 exported
# ---------------------
# Chunk 60000-61000 exported
# ---------------------
# Chunk 61000-62000 exported
# ---------------------
# Chunk 62000-63000 exported
# ---------------------
# Chunk 63000-64000 exported
# ---------------------
# Chunk 64000-65000 exported
# ---------------------
# Chunk 65000-66000 exported
# ---------------------
# Chunk 66000-67000 exported
# ---------------------
# Chunk 67000-68000 exported
# ---------------------
# Chunk 68000-69000 exported
# ---------------------
# Chunk 69000-70000 exported
# ---------------------
# Chunk 70000-71000 exported
# ---------------------
# Chunk 71000-72000 exported
# ---------------------
# Chunk 72000-73000 exported
# ---------------------
# Chunk 73000-74000 exported
# ---------------------
# Chunk 74000-75000 exported
# ---------------------
# Chunk 75000-76000 exported
# ---------------------
# Chunk 76000-77000 exported
# ---------------------
# Chunk 77000-78000 exported
# ---------------------
# Chunk 78000-79000 exported
# ---------------------
# Chunk 79000-80000 exported
# ---------------------
# Chunk 80000-81000 exported
# ---------------------
# Chunk 81000-82000 exported
# ---------------------
# Chunk 82000-83000 exported
# ---------------------
# Chunk 83000-84000 exported
# ---------------------
# Chunk 84000-85000 exported
# ---------------------
# Chunk 85000-86000 exported
# ---------------------
# Chunk 86000-87000 exported
# ---------------------
# Chunk 87000-88000 exported
# ---------------------
# Chunk 88000-89000 exported
# ---------------------
# Chunk 89000-90000 exported
# ---------------------
# Chunk 90000-91000 exported
# ---------------------
# Chunk 91000-92000 exported
# ---------------------
# Chunk 92000-93000 exported
# ---------------------
# Chunk 93000-94000 exported
# ---------------------
# Chunk 94000-95000 exported
# ---------------------
# Chunk 95000-96000 exported
# ---------------------
# Chunk 96000-97000 exported
# ---------------------
# Chunk 97000-97755 exported
# Export Successful

# %%
# Export cleaned spotify data
#spotify_filtered_df.to_csv("../Resources/spotify_cleaned.csv", index=False)
