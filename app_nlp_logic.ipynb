# %%
import nltk
import re
from nltk.tokenize import sent_tokenize, word_tokenize, WhitespaceTokenizer, SExprTokenizer, TabTokenizer   
from nltk import PorterStemmer
from nltk import word_tokenize
from nltk.corpus import stopwords
import pandas as pd
from nltk.corpus import words, stopwords

# %%
test_lyrics = "When you're all alone and blue. No one to tell your troubles to\
Remember me, I'm the one who loves you\
When this world turns you down\
Not a true friend can be found\
Remember me, I'm the one who loves you\
And through all kinds of weather\
You'll find, I'll NEVER change.\
Through the sunshine and the shadows\
I'll always be 5 the same\
We're together right or wrong\
Where you go I'll 400 tag along\
Remember me, I'm the one who loves you\
And through all kinds of weather?\
You'll find, I'll never change\
Through the sunshine and the shadows\
I'll always be the same\
We're together right or wrong\
Where you go I'll tag along!\
Remember me, I'm the one who loves you"

# %%
# How do we make sure the tabs and spaces don't precent the text from being a string?
# # Create space at the end of lines
# end_of_sen = re.compile(r'^[A-Z].*[\t]$', re.M)
# re.findall(test_lyrics)
# print(re.match(end_of_sen, test_lyrics))

# %%
# Aline's code
#def lyrics_BoW():
#     lyrics = "My house is beautiful"
#     # Tokenizing
#     words = nltk.word_tokenize(lyrics)
#     # Create an object of class PorterStemmer; set stopwords from NLTK as variable
#     porter = PorterStemmer()
#     stop_words = stopwords.words('english')
#     # Removing stopwords and stemming the remaining ones
#     filtered_lyrics = [porter.stem(w) for w in words if not w in stop_words]
#     # Creating frequency of each word and storing in dataframe
#     wordfreq = {}
#     for word in filtered_lyrics:
#         if word not in wordfreq.keys():
#             wordfreq[word] = 1
#         else:
#             wordfreq[word] += 1
#     # Updating dictionary with the genre (user input)
#     genre = "rock"
#     wordfreq.update({"genre": genre})
#     # Adding dictionary to dataframe to be used in the ML Model
#     wordfreq_df = pd.DataFrame(data=wordfreq, index=[0])
#     return wordfreq_df

# %%
# Create function
def lyrics_Bow():
    #Create an empty model_df. This list is going to be updated with final_df.columns.values
    model_df = pd.DataFrame(columns=['the', 'you', 'and', 'not', 'your', 'that', 'are', 'will', 'all', 'for', 'have', 'love', 'know', 'this', 'but', 'with', 'what', 'just', 'when', 'like', 'now', 'que', 'time', 'can', 'come', 'there', 'one', 'they', 'out', 'down', 'get', 'she', 'was', 'see', 'got', 'never', 'from', 'feel', 'want', 'let', 'make', 'way', 'say', 'take', 'would', 'day', 'babi', 'away', 'life', 'yeah', 'back', 'her', 'heart', 'here', 'how', 'could', 'night', 'need', 'our', 'look', 'where', 'eye', 'thing', 'world', 'more', 'caus', 'gonna', 'die', 'right', 'been', 'tell', 'think', 'who', 'through', 'man', 'live', 'again', 'give', 'too', 'onli', 'tri', 'whi', 'keep', 'dream', 'well', 'mind', 'still', 'his', 'long', 'girl', 'wanna', 'find', 'fall', 'around', 'good', 'about', 'some', 'over', 'littl', 'turn', 'hand', 'then', 'noth', 'light', 'said', 'call', 'everi', 'alway', 'were', 'did', 'into', 'wait', 'leav', 'home', 'had', 'hold', 'run', 'walk', 'ever', 'them', 'lie', 'face', 'end', 'hear', 'gone', 'head', 'believ', 'everyth', 'has', 'cri', 'alon', 'hey', 'their', 'someth', 'insid', 'befor', 'word', 'stay', 'place', 'much', 'chang', 'god', 'stand', 'these', 'better', 'last', 'friend', 'soul', 'anoth', 'left', 'new', 'him', 'than', 'stop', 'tonight', 'burn', 'sun', 'off', 'por', 'play', 'thought', 'sing', 'show', 'lost', 'peopl', 'made', 'break', 'und', 'start', 'should', 'realli', 'chorus', 'hard', 'sky', 'old', 'even', 'boy', 'pleas', 'song', 'care', 'without', 'hope', 'watch', 'pain', 'amor', 'move', 'wrong', 'put', 'free', 'gotta', 'name', 'same', 'blue', 'con', 'danc', 'talk', 'seem', 'own', 'mine', 'dark', 'far', 'tear', 'true', 'fire', 'use', 'dead', 'bring', 'fuck', 'other', 'sin', 'someon', 'myself', 'forev', 'close', 'sleep', 'rain', 'those', 'must', 'una', 'les', 'sweet', 'mean', 'fight', 'rememb', 'star', 'while', 'kiss', 'kill', 'high', 'breath', 'doe', 'yes', 'wish', 'che', 'real', 'smile', 'two', 'cold', 'lord', 'year', 'open', 'fear', 'done', 'side', 'fli', 'black', 'line', 'rock', 'blood', 'lose', 'found', 'onc', 'non', 'door', 'bad', 'ooh', 'wonder', 'como', 'enough', 'para', 'sound', 'togeth', 'mayb', 'los', 'help', 'shine', 'mani', 'heaven', 'becaus', 'work', 'touch', 'behind', 'yourself', 'today', 'big', 'might', 'death', 'hate', 'miss', 'ride', 'street', 'came', 'ask', 'hide', 'everybodi', 'save', 'till', 'may', 'beauti', 'roll', 'sure', 'deep', 'arm', 'son', 'wind', 'bodi', 'forget', 'happi', 'understand', 'best', 'town', 'war', 'listen', 'seen', 'der', 'sometim', 'lone', 'hell', 'morn', 'until', 'set', 'hurt', 'told', 'first', 'knew', 'goe', 'round', 'alright', 'music', 'sea', 'truth', 'qui', 'beat', 'las', 'pass', 'under', 'del', 'late', 'after', 'ani', 'ground', 'fool', 'pas', 'broken', 'goodby', 'das', 'des', 'kind', 'wall', 'angel', 'est', 'road', 'reason', 'dan', 'money', 'chanc', 'mai', 'part', 'matter', 'learn', 'els', 'rise', 'pour', 'saw', 'grow', 'sit', 'land', 'fade', 'air', 'took', 'nobodi', 'fill', 'easi', 'game', 'follow', 'wake', 'anyth', 'aliv', 'solo', 'water', 'heard', 'though', 'white', 'vida', 'voic', 'woman', 'blind', 'each', 'citi', 'young', 'lay', 'moon', 'reach', 'readi', 'fine', 'soon', 'shit', 'along', 'crazi', 'past', 'red', 'room', 'such', 'step', 'scream', 'tomorrow', 'control', 'memori', 'strong', 'hit', 'everyon', 'wast', 'men', 'earth', 'upon', 'final', 'shake', 'abov', 'moment', 'rest', 'guess', 'hous', 'born', 'somebodi', 'feet', 'mas', 'sad', 'laugh', 'happen', 'went', 'cest', 'blow', 'meet', 'whole', 'lover', 'drive', 'car', 'lead', 'veri', 'promis', 'bed', 'apart', 'empti', 'shadow', 'full', 'begin', 'pull', 'child', 'pretti', 'drink', 'pray', 'king', 'cut', 'power', 'gave', 'hay', 'peac', 'hang', 'next', 'ser', 'mother', 'between', 'pay', 'carri', 'tire', 'speak', 'lot', 'tree', 'den', 'skin', 'tout', 'til', 'slow', 'sinc', 'anymor', 'kid', 'clear', 'mich', 'jesus', 'differ', 'fast', 'becom', 'nigga', 'gun', 'nos', 'river', 'faith', 'floor', 'cross', 'ladi', 'near', 'fun', 'ring', 'answer', 'afraid', 'jag', 'repeat', 'great', 'stori', 'yet', 'cannot', 'hot', 'wir', 'hour', 'summer', 'stone', 'bleed', 'sign', 'mir', 'lyric', 'children', 'trust', 'wild', 'felt', 'troubl', 'honey', 'sick', 'perfect', 'human', 'bright', 'mama', 'parti', 'train', 'plan', 'sorri', 'plus', 'hair', 'secret', 'silenc', 'tast', 'brother', 'throw', 'within', 'per', 'push', 'somewher', 'three', 'cloud', 'shall', 'low', 'window', 'knee', 'lip', 'futur', 'dear', 'search', 'drop', 'det', 'cool', 'flame', 'outsid', 'worri', 'bout', 'goin', 'met', 'stare', 'sight', 'most', 'mon', 'across', 'wear', 'wave', 'tus', 'pick', 'send', 'bone', 'flow', 'piec', 'soy', 'thank', 'mis', 'straight', 'blame', 'catch', 'tight', 'mile', 'holi', 'darl', 'mouth', 'which', 'moi', 'against', 'mad', 'both', 'share', 'caught', 'father', 'read', 'warm', 'wing', 'belong', 'damn', 'eat', 'win', 'sens', 'comm', 'fell', 'evil', 'dem', 'pictur', 'second', 'nowher', 'dog', 'rule', 'mal', 'mountain', 'joy', 'mit', 'top', 'och', 'tan', 'som', 'bit', 'cover', 'point', 'thousand', 'hoy', 'gold', 'bell', 'devil', 'bird', 'sur', 'quit', 'brain', 'return', 'build', 'kick', 'rose', 'bitch', 'babe', 'guy', 'whoa', 'shame', 'mein', 'space', 'whisper', 'cos', 'write', 'dir', 'count', 'slip', 'ver', 'desir', 'nice', 'weak', 'rais', 'jai', 'ocean', 'number', 'drown', 'spirit', 'scare', 'strang', 'half', 'known', 'pretend', 'worth', 'someday', 'act', 'beyond', 'fair', 'million', 'finger', 'question', 'doubt', 'meant', 'smoke', 'comin', 'flesh', 'dawn', 'daddi', 'storm', 'hole', 'color', 'jump', 'remain', 'etern', 'nothin', 'buy', 'anyon', 'dress', 'minut', 'pra', 'snow', 'dig', 'forc', 'spend', 'shot', 'everyday', 'chain', 'dri', 'grace', 'green', 'glori', 'everywher', 'freedom', 'realiz', 'lock', 'pride', 'whatev', 'feed', 'mistak', 'vers', 'fate', 'escap', 'wash', 'mess', 'sand', 'front', 'forgiv', 'winter', 'tanto', 'magic', 'flower', 'closer', 'safe', 'sol', 'bless', 'suffer', 'longer', 'hello', 'san', 'grave', 'alreadi', 'yesterday', 'wide', 'radio', 'sorrow', 'ten', 'phone', 'crawl', 'surviv', 'tie', 'exist', 'anyway', 'spin', 'insan', 'nous', 'slowli', 'ear', 'crowd', 'clean', 'natur', 'knock', 'four', 'poor', 'loud', 'shoe', 'bar', 'ass', 'lovin', 'higher', 'race', 'silent', 'lift', 'destroy', 'soft', 'paint', 'mar', 'dirti', 'check', 'held', 'vie', 'shout', 'sail', 'twist', 'guitar', 'simpl', 'deni', 'fail', 'van', 'famili', 'vision', 'toi', 'lookin', 'track', 'broke', 'dia', 'state', 'welcom', 'ghost', 'almost', 'shut', 'entr', 'somehow', 'glass', 'yea', 'gent', 'choos', 'bin', 'glad', 'shoot', 'ell', 'small', 'hill', 'wine', 'treat', 'dos', 'stranger', 'regret', 'refrain', 'machin', 'problem', 'feelin', 'sister', 'era', 'steal', 'endless', 'vai', 'awak', 'key', 'grand', 'age', 'bridg', 'dust', 'wit', 'merci', 'wheel', 'ere', 'crack', 'taken', 'prais', 'heal', 'queen', 'mirror', 'corner', 'ago', 'buri', 'book', 'climb', 'okay', 'cloth', 'band', 'school', 'stick', 'circl', 'don', 'strength', 'five', 'countri', 'beneath', 'sunshin', 'sabe', 'alma', 'ice', 'bound', 'less', 'sell', 'tongu', 'path', 'travel', 'hat', 'rather', 'heat', 'confus', 'golden', 'mari', 'singl', 'ahead', 'bye', 'silver', 'tryin', 'doo', 'mes', 'sai', 'chase', 'few', 'sein', 'scene', 'smell', 'funni', 'enemi', 'swear', 'ball', 'beg', 'sind', 'prayer', 'wound', 'ton', 'disappear', 'besid', 'hace', 'toda', 'ignor', 'style', 'brought', 'given', 'quiet', 'rage', 'mano', 'realiti', 'sink', 'spread', 'crime', 'vain', 'nadi', 'fallen', 'self', 'decid', 'ella', 'fue', 'imagin', 'stuck', 'view', 'vas', 'kept', 'demon', 'sui', 'busi', 'record', 'law', 'choic', 'har', 'fit', 'remind', 'emot', 'field', 'crash', 'suppos', 'sen', 'danger', 'letter', 'midnight', 'com', 'nation', 'edg', 'surpris', 'murder', 'deal', 'complet', 'loos', 'price', 'instrument', 'luck', 'rip', 'drift', 'poison', 'battl', 'livin', 'gimm', 'gettin', 'haunt', 'sex', 'proud', 'heavi', 'guid', 'drag', 'middl', 'bare', 'dare', 'bang', 'pure', 'embrac', 'aus', 'suck', 'stupid', 'fake', 'week', 'news', 'tes', 'master', 'float', 'satisfi', 'sent', 'christ', 'fait', 'scar', 'bear', 'dime', 'quick', 'het', 'poi', 'swing', 'below', 'prove', 'figur', 'diamond', 'none', 'instead', 'pleasur', 'curs', 'rich', 'cat', 'spent', 'seek', 'paper', 'mysteri', 'passion', 'brand', 'bomb', 'luz', 'bitter', 'tender', 'fact', 'job', 'bet', 'cast', 'trip', 'pack', 'explain', 'talkin', 'lucki', 'special', 'mark', 'form', 'shoulder', 'warn', 'creat', 'seven', 'ship', 'bist', 'miseri', 'sunday', 'six', 'tune', 'wrap', 'pop', 'surround', 'doin', 'hero', 'gate', 'comfort', 'han', 'rush', 'drug', 'fuckin', 'least', 'short', 'cruel', 'par', 'rhyme', 'written', 'swallow', 'wander', 'reflect', 'dice', 'tide', 'join', 'bottl', 'steel', 'paradis', 'mia', 'cant', 'wife', 'shore', 'leg', 'somethin', 'draw', 'slave', 'march', 'algo', 'beso', 'swim', 'built', 'tempo', 'women', 'fix', 'trap', 'torn', 'vein', 'releas', 'hors', 'casa', 'spell', 'glow', 'grab', 'drum', 'bite', 'brown', 'won', 'i’m', 'sugar', 'forgotten', 'stronger', 'rhythm', 'victim', 'messag', 'later', 'person', 'darlin', 'poco', 'huh', 'dat', 'sudden', 'stood', 'att', 'runnin', 'season', 'surrend', 'bore', 'crush', 'histori', 'wont', 'luna', 'weight', 'lust', 'dolor', 'park', 'expect', 'speed', 'shade', 'calm', 'bow', 'bend', 'mig', '
 'hoe', 'cop', 'sou', 'seat', 'whose', 'forgot', 'bother', 'chest', 'situat', 'candl', 'cash', 'valley', 'quil', 'further', 'unit', 'mira', 'aim', 'journey', 'cell', 'gray', 'vita', 'tag', 'throat', 'heartach', 'tortur', 'mot', 'cara', 'imag', 'min', 'birth', 'woo', 'refus', 'sword', 'fortun', 'ces', 'ima', 'older', 'spoken', 'chose', 'motion', 'motherfuck', 'fals', 'enjoy', 'fort', 'creep', 'sayin', 'trade', 'hoo', 'monkey', 'food', 'worship', 'ancient', 'confess', 'stole', 'forward', 'fallin', 'favorit', 'toe', 'toy', 'nose', 'favor', 'american', 'class', 'cigarett', 'maria', 'intent', 'pill', 'spill', 'cost', 'shed', 'probabl', 'among', 'tanta', 'dar', 'clown', 'consum', 'saint', 'fai', 'connect', 'chao', 'mix', 'dun', 'goodnight', 'amour', 'sola', 'numb', 'nest', 'island', 'wipe', 'await', 'spot', 'merri', 'hombr', 'chair', 'press', 'divid', 'bust', 'bem', 'compani', 'lick', 'boot', 'loneli', 'constant', 'dad', 'bei', 'cage', 'mañana', 'flight', 'armi', 'mood', 'killer', 'darkest', 'drain', 'underground', 'polic', 'fresh', 'boogi', 'lean', 'pale', 'explod', 'sexi', 'rape', 'dick', 'recal', 'exact', 'freez', 'savior', 'piti', 'except', 'candi', 'frame', 'honest', 'religion', 'hunger', 'station', 'although', 'bus', 'onto', 'pum', 'aux', 'trail', 'mil', 'spark', 'decay', 'bass', 'demand', 'command', 'beach', 'destin', 'shi', 'greed', 'lack', 'ela', 'via', 'vert', 'whore', 'sat', 'monster', 'stumbl', 'roam', 'threw', 'screen', 'thou', 'harm', 'gli', 'date', 'cheap', 'north', 'root', 'led', 'rough', 'loco', 'energi', 'despair', 'gaze', 'guilti', 'joe', 'asid', 'addict', 'seal', 'super', 'iron', 'wisdom', 'scratch', 'papa', 'smash', 'throne', 'deceiv', 'forth', 'coffe', 'ves', 'weari', 'posit', 'ugli', 'shop', 'hood', 'shell', 'horizon', 'becam', 'piss', 'blade', 'playin', 'grew', 'often', 'gal', 'victori', 'receiv', 'takin', 'lightn', 'allow', 'mornin', 'hammer', 'telephon', 'admit', 'rat', 'flag', 'truli', 'doom', 'dis', 'loss', 'sacr', 'limit', 'bigger', 'afternoon', 'fed', 'engin', 'foolish', 'jean', 'shock', 'breed', 'greatest', 'mental', 'tal', 'angri', 'ayer', 'finish', 'row', 'convers', 'plastic', 'grip', 'creation', 'snake', 'regard', 'tick', 'fan', 'lit', 'holiday', 'int', 'sue', 'steadi', 'coat', 'funki', 'cheat', 'sort', 'drip', 'abus', 'possess', 'undon', 'vocal', 'hunt', 'month', 'possibl', 'design', 'depend', 'sole', 'daylight', 'sous', 'treasur', 'california', 'mare', 'strip', 'hum', 'trembl', 'invit', 'rope', 'flood', 'ticket', 'crew', 'spoke', 'sheet', 'wreck', 'cowboy', 'needl', 'common', 'lung', 'monday', 'friday', 'girlfriend', 'piano', 'mission', 'rescu', 'lazi', 'coupl', 'eight', 'hai', 'split', 'mortal', 'guard', 'societi', 'hotel', 'easili', 'fashion', 'heel', 'creatur', 'sittin', 'defeat', 'ben', 'excit', 'hung', 'lake', 'tower', 'dive', 'curtain', 'gas', 'restless', 'canto', 'dum', 'grant', 'unless', 'cheek', 'type', 'crumbl', 'hail', 'chosen', 'sunni', 'handl', 'lion', 'burnin', 'disco', 'bank', 'match', 'twenti', 'aris', 'replac', 'you’r', 'score', 'bon', 'continu', 'stretch', 'inspir', 'din', 'forest', 'callin', 'coast', 'mort', 'belief', 'sunlight', 'plant', 'sever', 'whip', 'ray', 'oder', 'descend', 'simpli', 'singin', 'mankind', 'violent', 'lane', 'void', 'hop', 'sunset', 'thru', 'silli', 'corps', 'lass', 'behold', 'normal', 'agre', 'abandon', 'weapon', 'wed', 'bella', 'reveng', 'tini', 'justic', 'weekend', 'mic', 'nor', 'bloom', 'sam', 'affair', 'leader', 'aah', 'nerv', 'hush', 'historia', 'caress', 'either', 'discov', 'leavin', 'helpless', 'ghetto', 'bread', 'dancin', 'tant', 'hmm', 'vive', 'pace', 'relax', 'jam', 'brick', 'dei', 'complain', 'burden', 'sunris', 'also', 'linger', 'jungl', 'hopeless', 'abl', 'bop', 'pillow', 'damag', 'mister', 'mask', 'itself', 'drove', 'pump', 'ska', 'boss', 'himself', 'list', 'whiskey', 'moral', 'affect', 'conquer', 'rosa', 'tumbl', 'album', 'mend', 'warrior', 'sinner', 'tip', 'express', 'loser', 'chant', 'crave', 'crystal', 'thrown', 'quell', 'bay', 'bee', 'fruit', 'hangin', 'billi', 'hollywood', 'parad', 'weed', 'switch', 'wat', 'stab', 'vent', 'collect', 'truck', 'instant', 'terra', 'skull', 'ora', 'fare', 'rebel', 'meat', 'autumn', 'bom', 'london', 'jos', 'deliv', 'perdido', 'doll', 'downtown', 'pink', 'owe', 'howl', 'heartbeat', 'core', 'butterfli', 'chick', 'della', 'bastard', 'wer', 'easier', 'clue', 'shiver', 'pool', 'presenc', 'dread', 'surfac', 'conscienc', 'zero', 'blaze', 'squeez', 'blast', 'dope', 'bruis', 'tea', 'honor', 'lamb', 'flor', 'whistl', 'roof', 'givin', 'gang', 'bewar', 'tomb', 'lei', 'wow', 'clap', 'squar', 'forma', 'workin', 'rider', 'appl', 'modern', 'tellin', 'magazin', 'cha', 'coz', 'inner', 'impress', 'drawn', 'smart', 'harmoni', 'govern', 'quest', 'gran', 'volar', 'bliss', 'polit', 'dim', 'tour', 'pant', 'cheer', 'quer', 'familiar', 'fought', 'roar', 'pen', 'obsess', 'centuri', 'failur', 'jail', 'confid', 'meg', 'kneel', 'spare', 'pin', 'import', 'mourn', 'yearn', 'guilt', 'solut', 'terr', 'focus', 'cling', 'concret', 'horror', 'sore', 'dom', 'unfold', 'bounc', 'nun', 'goal', 'selfish', 'knowledg', 'awaken', 'bath', 'delight', 'fond', 'parol', 'courag', 'serious', 'whether', 'ter', 'sweetest', 'useless', 'film', 'ole', 'male', 'alcohol', 'sake', 'sway', 'relat', 'tra', 'stair', 'parent', 'advic', 'grind', 'negro', 'riot', 'blown', 'burst', 'quel', 'size', 'sheep', 'fold', 'captur', 'dies', 'lee', 'dwell', 'frighten', 
                                    'proof', 'earn', 'preacher', 'base', 'belli', 'mach', 'lullabi', 'louder', 'panic', 'flore', 'social', 'rang', 'cock', 'shown', 'sung', 'understood', 'progress', 'strand', 'role', 'bride', 'crook', 'fiesta', 'thug', 'bind', 'quoi', 'shove', 'gangsta', 'cherri', 'mill', 'oil', 'dude', 'deed', 'tres', 'ama', 'drank', 'strain', 'dragon', 'wrist', 'team', 'thirst', 'playa', 'pronto', 'avoid', 'inch', 'ecstasi', 'inform', 'mud', 'deus', 'purpl', 'nog', 'razor', 'rust', 'femm', 'famous', 'defin', 'bold', 'bibl', 'pit', 'burnt', 'choir', 'trial', 'essa', 'entertain', 'penni', 'comment', 'rio', 'bras', 'demis', 'serpent', 'emerg', 'rue', 'stolen', 'alarm', 'hug', 'arrow', 'templ', 'rejoic', 'code', 'dancer', 'odd', 'gloria', 'map', 'adio', 'presid', 'aha', 'afford', 'southern', 'mala', 'drivin', 'rag', 'organ', 'spite', 'boil', 'movement', 'highest', 'pens', 'plate', 'cake', 'bobbi', 'slam', 'jet', 'vom', 'chanson', 'halt', 'soar', 'bob', 'swell', 'pot', 'christian', 'gen', 'risk', 'scienc', 'plead', 'drinkin', 'maker', 'amen', 'giant', 'level', 'raw', 'ess', 'flew', 'languag', 'deepest', 'motor', 'visit', 'sweeter', 'pose', 'cradl', 'obey', 'goddamn', 'threat', 'driver', 'attract', 'buddi', 'public', 'avenu', 'tempt', 'shakin', 'mie', 'bein', 'daili', 'sta', 'stack', 'nasti', 'center', 'tame', 'pierc', 'obvious', 'worthi', 'consid', 'gar', 'sparkl', 'fulfil', 'prophet', 'vanish', 'pan', 'slap', 'spoon', 'thread', 'china', 'chew', 'bump', 'humbl', 'claw', 'preach', 'cadillac', 'mate', 'bond', 'grain', 'saniti', 'blank', 'degre', 'wither', 'snap', 'fog', 'despis', 'endur', 'luce', 'sip', 'pine', 'alley', 'rearrang', 'donn', 'traffic', 'sincer', 'liberti', 'volta', 'gypsi', 'pare', 'struck', 'chip', 'puls', 'scent', 'lame', 'stir', 'chop', 'condemn', 'cleans', 'neither', 'buzz', 'tai', 'indian', 'muss', 'rub', 'prima', 'blowin', 'cancer', 'solitud', 'driven', 'klein', 'sooner', 'success', 'media', 'blacken', 'foreign', 'greater', 'sourc', 'boyfriend', 'medicin', 'rare', 'lace', 'colder', 'camera', 'bail', 'tool', 'oper', 'havin', 'interest', 'paul', 'vet', 'runaway', 'slept', 'footstep', 'sixteen', 'priest', 'egg', 'intro', 'turnin', 'alien', 'vengeanc', 'stake', 'sonn', 'sooth', 'rein', 'watchin', 'peel', 'stormi', 'player', 'dinner', 'hardest', 'respons', 'worm', 'tak', 'aye', 'perhap', 'blond', 'critic', 'stomach', 'toast', 'oye', 'bug', 'crucifi', 'sailor', 'steam', 'clever', 'claus', 'uncl', 'graviti', 'reap', 'farm', 'opinion', 'whom', 'grasp', 'mamma', 'tore', 'dale', 'hurrican', 'thief', 'vibe', 'shini', 'sidewalk', 'conscious', 'glove', 'perform', 'winner', 'disappoint', 'ann', 'satellit', 'tattoo', 'tas', 'deg', 'usual', 'cocain', 'tot', 'tuesday', 'tension', 'rout', 'educ', 'bitt', 'zombi', 'furi', 'alter', 'lend', 'valu', 'coal', 'mommi', 'velvet', 'blanket', 'drama', 'bowl', 'orang', 'reborn', 'angst', 'lotta', 'lyin', 'conceal', 'rid', 'ideal', 'dal', 'willi', 'sentenc', 'dell', 'adió', 'tar', 'button', 'nao', 'strap', 'display', 'fra', 'tap', 'hon', 'signal', 'sul', 'shook', 'dot', 'jewel', 'vine', 'redeem', 'musica', 'cow', 'termin', 'pattern', 'throughout', 'younger', 'coin', 'verso', 'deaf', 'expos', 'compass', 'donna', 'num', 'describ', 'lower', 'brush', 'tangl', 'instinct', 'effect', 'approach', 'breast', 'volt', 'dart', 'wil', 'franc', 'repli', 'provid', 'declar', 'nuclear', 'swore', 'llama', 'vino', 'solv', 'distort', 'lair', 'rubber', 'factori', 'post', 'artist', 'peter', 'biggest', 'brutal', 'extrem', 'english', 'jerk', 'debt', 'perch', 'shield', 'esperanza', 'haar', 'doi', 'model', 'weigh', 'resurrect', 'alto', 'curl', 'cent', 'june', 'slice', 'sha', 'olen', 'insecur', 'coward', 'finn', 'georgia', 'cute', 'cruis', 'mexico', 'invad', 'jealousi', 'halo', 'tras', 'beaten', 'shelf', 'motiv', 'twelv', 'rumor', 'swept', 'anna', 'contain', 'wort', 'ate', 'sleigh', 'champagn', 'aun', 'defens', 'deceit', 'weird', 'relief', 'product', 'dip', 'singer', 'vera', 'spi', 'target', 'souvenir', 'stereo', 'rude', 'reli', 'harvest', 'liquid', 'fucker', 'exit', 'woe', 'web', 'facil', 'princess', 'muscl', 'booti', 'blur', 'duck', 'idiot', 'breakdown', 'liber', 'sow', 'flyin', 'symphoni', 'automat', 'robot', 'realm', 'practic', 'distract', 'sane', 'april', 'gear', 'vicious', 'womb', 'major', 'willow', 'neighborhood', 'static', 'wealth', 'reel', 'yer', 'joint', 'venus', 'wolv', 'lala', 'africa', 'homi', 'sock', 'arena', 'support', 'credit', 'regga', 'repres', 'miro', 'matin', 'sleepi', 'worthless', 'video', 'griev', 'branch', 'achiev', 'maze', 'knockin', 'correct', 'dial', 'file', 'soi', 'filthi', 'jim', 'juic', 'convict', 'cycl', 'perdu', 'disturb', 'rapper', 'forgiven', 'sinn', 'tend', 'corpor', 'tunnel', 'loca', 'dai', 'legend', 'idol', 'dyin', 'forsaken', 'fella', 'physic', 'tragic', 'gris', 'forti', 'dough', 'england', 'denial', 'liv', 'local', 'urg', 'taxi', 'ambit', 'voyag', 'mere', 'dull', 'unleash', 'tread', 'smokin', 'william', 'gleam', 'civil', 'defi', 'heed', 'bull', 'host', 'villag', 'unkind', 'altar', 'sal', 'lisa', 'bunch', 'pardon', 'despit', 'ignit', 'cotton', 'phase', 'porta', 'tue', 'link', 'intern', 'seventeen', 'shes', 'coffin', 'hound', 'health', 'frei', 'alibi', 'bled', 'rubi', 'leaf', 'attempt', 'thumb', 'rode', 'sober', 'buen', 'cum', 'crimson', 'height', 'frost', 'acid', 'net', 'pimp', 'font', 'shepherd', 'hunter', 'jive', 'prevail', 'jaw', 'circus', 'background', 'fairi', 'symbol', 'sulla', 'peak', 'plot', 'manag', 'safeti', 'sleepless', 'chez', 'liquor', 'narrow', 'object', 'there’', 'meal', 'unholi
tut', 'sil', 'obscur', 'smack', 'slut', 'childhood', 'memoria', 'lipstick', 'shinin', 'photo', 'enchant', 'hei', 'ira', 'farther', 'sport', 'gasolin', 'latest', 'rosi', 'fiend', 'palac', 'aboard', 'strife', 'anchor', 'corn', 'clay', 'café', 'dah', 'dizzi', 'spray', 'messiah', 'brake', 'pleur', 'cafe', 'sum', 'pet', 'jade', 'combin', 'tod', 'hur', 'apathi', 'crippl', 'axe', 'rabbit', 'sanctuari', 'valor', 'transform', 'uniform', 'confront', 'swift', 'barrel', 'filth', 'lune', 'masquerad', 'mississippi', 'chime', 'railroad', 'qua', 'actual', 'gloom', 'perd', 'abr', 'inn', 'phantom', 'appeal', 'plug', 'vaniti', 'poni', 'fearless', 'stitch', 'fragment', 'clutch', 'squad', 'makeup', 'stalk', 'surf', 'outer', 'basement', 'obscen', 'passé', 'fiddl', 'steve', 'boulevard', 'chart', 'arrang', 'increas', 'weer', 'leve', 'evolut', 'wooden', 'kickin', 'logic', 'feat', 'gotten', 'mire', 'hid', 'wasteland', 'fighter', 'husband', 'jumpin', 'maim', 'program', 'majesti', 'retreat', 'daze', 'challeng', 'subject', 'standard', 'jazz', 'opportun', 'miser', 'col', 'legion', 'submit', 'cough', 'teen', 'wilder', 'pone', 'studi', 'jacket', 'overflow', 'suprem', 'butcher', 'balloon', 'pushin', 'pane', 'stomp', 'judgment', 'industri', 'introduc', 'lai', 'venir', 'taint', 'counti', 'fleet', 'allah', 'groovi', 'chrome', 'blah', 'genocid', 'unreal', 'slumber', 'thiev', 'frank', 'lurk', 'unhappi', 'chico', 'dusk', 'lap', 'dynamit', 'twin', 'dub', 'thirsti', 'skirt', 'hopin', 'predict', 'heroin', 'wonderland', 'scari', 'steer', 'ana', 'screamin', 'routin', 'contr', 'tooth', 'eden', 'remedi', 'cloudi', 'adam', 'perro', 'amus', 'closet', 'ner', 'ano', 'western', 'ness', 'amiga', 'beef', 'featur', 'robin', 'decad', 'bald', 'whine', 'chees', 'feu', 'dish', 
                                    'leva', 'misunderstood', 'misti', 'psycho', 'spotlight', 'reviv', 'suitcas', 'geld', 'cunt', 'mellow', 'poetri', 'bean', 'print', 'confin', 'inhal', 'idl', 'juro', 'allen', 'upp', 'statu', 'bluebird', 'uniti', 'reckless', 'robe', 'leer', 'menschen', 'etc', 'raindrop', 'puzzl', 'wax', 'foss', 'junk', 'skeleton', 'grade', 'effort', 'hippi', 'fil', 'curv', 'disconnect', 'carol', 'strung', 'cousin', 'radiat', 'pal', 'stiff', 'trend', 'lento', 'aqu', 'terrifi', 'fore', 'vide', 'channel', 'parc', 'stern', 'cope', 'garbag', 'admir', 'blister', 'sull', 'pitch', 'carn', 'slippin', 'dong', 'we’r', 'honki', 'shark', 'afar', 'jest', 'superman', 'sublim', 'hiphop', 'billion', 'romeo', 'banana', 'richard', 'jung', 'fiel', 'noos', 'beggin', 'trunk', 'ink', 'mash', 'succeed', 'toni', 'spinnin', 'powder', 'fou', 'motherfuckin', 'hun', 'butter', 'fur', 'disagre', 'assur', 'drunken', 'tuck', 'keeper', 'broad', 'maid', 'flock', 'gib', 'tango', 'berlin', 'handsom', 'blunt', 'qual', 'inject', 'timeless', 'cor', 'bonni', 'clone', 'mall', 'wink', 'blanca', 'meaningless', 'crap', 'legal', 'hypocrit', 'aid', 'brooklyn', 'term', 'layin', 'conceiv', 'seel', 'slick', 'vega', 'tax', 'virtu', 'unabl', 'distress', 'bla', 'ember', 'wee', 'beckon', 'galaxi', 'ley', 'mous', 'issu', 'absurd', 'zoo', 'rocki', 'jackson', 'neat', 'itch', 'insect', 'starlight', 'shred', '000', 'segundo', 'bonito', 'mag', 'scarlet', 'lunch', 'leak', 'bah', 'consol', 'flirt', 'absenc', 'comprehend', 'hin', 'scum', 'stride', 'fingertip', 'lua', 'translat', 'reput', 'starri', 'belt', 'sig', 'tribe', 'illumin', 'knowin', 'forg', 'minor', 'behav', 'oli', 'troi', 'passer', 'vela', 'anyhow', 'mock', 'bir', 'intens', 'saddl', 'glue', 'kai', 'rave', 'retir', 'vara', 'molli', 'forbidden', 'combat', 'trippin', 'deepli', 'puttin', 'silk', 'paranoia', 'whirl', 'duti', 'ditch', 'shave', 'sicken', 'premier', 'reliev', 'restor', 'unawar', 'dash', 'gore', 'kissin', 'temperatur', 'messin', 'rumbl', 'argu', 'freeway', 'unspoken', 'passag', 'fora', 'cosmic', 'betti', 'request', 'bucket', 'proper', 'ace', 'gown', 'chapter', 'digit', 'actor', 'cambia', 'creator', 'skate', 'askin', 'flown', 'nurs', 'sim', 'waist', 'collar', 'current', 'naiv', 'flaw', 'comb', 'headlight', 'suav', 'ascend', 'cree', 'vete', 'pledg', 'mistaken', 'method', 'vagu', 'maiden', 'element', 'entir', 'alleluia', 'oft', 'rug', 'aura', 'guest', 'chamber', 'sere', 'jukebox', 'skinni', 'hurtin', 'eager', 'droit', 'glisten', 'assassin', 'landscap', 'seein', 'senseless', 'lili', 'auto', 'structur', 'assum', 'spawn', 'proclaim', 'threaten', 'swirl', 'curious', 'complex', 'uptown', '100', 'advanc', 'hah', 'dug', 'lucif', 'cruz', 'jamaica', 'flavor', 'anguish', 'chat', 'observ', 'yang', 'nickel', 'booz', 'sew', 'stai', 'naughti', 'champion', 'forsak', 'seventh', 'capit', 'writer', 'bake', 'insist', 'wel', 'gee', 'colleg', 'kad'])
    # User input 
    lyrics = test_lyrics
    # Tokenize by words
    words = nltk.word_tokenize(lyrics)
    # Create an object of class PorterStemmer; set stopwords from NLTK as variable
    porter = PorterStemmer()
    stop_words = stopwords.words('english')
    # Removing stopwords and stemming the remaining ones
    filtered_lyrics = [porter.stem(w) for w in words if not w in stop_words]
    # Creating frequency of each word and storing in dataframe
    wordfreq = {}
    for word in filtered_lyrics:
        if word not in wordfreq.keys():
            wordfreq[word] = 1
        else:
            wordfreq[word] += 1
        # Updating dictionary with the genre (user input)
    genre = "rock"
    wordfreq.update({"genre": genre})
        # Adding dictionary to dataframe to be used in the ML Model

    for key,value in wordfreq.items():
        if key in model_df.columns.values:
            model_df = model_df.append({key:value},ignore_index = True)
        elif key == "genre":
            model_df = model_df.append({key:value},ignore_index = True)

    model_df = model_df.fillna(0)
