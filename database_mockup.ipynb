# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import psycopg2
from config import db_pwd

# %%
mock_data= {'title':["Everything For A Dry Day",
                      "Heat Of A Storm",
                      "Memories For The Good Times",
                      "Home Of Father",
                     "For His Dreams",
                     "Don't Need My Girl",
                     "Rodeo And Choice",
                     "Dirt And Heart",
                     "Storm And Fire",
                     "You're My One And Only",
                     "You Cheated",
                     "Honey, Love Me Or Leave Me",
                     "I Said She Wants You",
                     "I Heard I'm Riding Alone",
                     "She Said He Belongs On The Road",
                     "Stars",
                     "Dirt Of A Woman",
                     "Soul Of The Good Life",
                     "With Her Worries",
                     "Home Of My Best Friend",
                     "There Goes World",
                     "Best And Man",
                     "Sweet And Games",
                     "Morning And Man",
                     "Honey, Let's Go",
                     "Sweetie, Hold Me Tonight",
                     "Babe, Set Me Free",
                     "I Love He Loves You",
                     "He's Trouble",
                     "I Said We Can't Stay"],
            'year': np.random.randint(1920,2020,size=30),
             'roadcuts': np.random.randint(0,100,size=30),
             'shiners': np.random.randint(0,100,size=30),
             'magret': np.random.randint(0,100,size=30),
             'flames': np.random.randint(0,100,size=30),
             'might': np.random.randint(0,100,size=30),
             'Svizzera': np.random.randint(0,100,size=30),
             'baseburner': np.random.randint(0,100,size=30),
             'mattock': np.random.randint(0,100,size=30),
             'bedform': np.random.randint(0,100,size=30),
             'malodor': np.random.randint(0,100,size=30),
             'duranguense': np.random.randint(0,100,size=30),
             'Cyril': np.random.randint(0,100,size=30),
             'cobbles': np.random.randint(0,100,size=30),
             'bloodmobile': np.random.randint(0,100,size=30),
             'farside': np.random.randint(0,100,size=30),
             'comportments': np.random.randint(0,100,size=30),
             'angioedemas': np.random.randint(0,100,size=30),
             'eggcorns': np.random.randint(0,100,size=30),
             'bluffer': np.random.randint(0,100,size=30),
             'feather-grass': np.random.randint(0,100,size=30),
            "genre": ["rock",
                      "pop",
                      "electronic",
                      "alternative",
                      "pop-rock",
                      "pop",
                      "electronic",
                      "pop",
                      "country",
                      "pop",
                      "country",
                      "alternative",
                      "R&B",
                      "jazz",
                      "pop",
                      "jazz",
                      "rock",
                      "country",
                      "pop-rock",
                      "rock",
                      "country",
                      "R&B",
                      "electronic",
                      "alternative",
                      "jazz",
                      "blues",
                      "pop",
                      "pop",
                      "rock",
                      "country"],
            "successful" : np.random.randint(0,2,size=30),
           "is_test" : np.random.randint(0,2,size=30)}

# %%
mock_data_df = pd.DataFrame(mock_data)
mock_data_df
# Out:
#                               title  year  roadcuts  shiners  magret  flames  \
# 0          Everything For A Dry Day  1989        77       24       3      90
# 1                   Heat Of A Storm  1928        27        8      20      43
# 2       Memories For The Good Times  1924        87       77      41       2
# 3                    Home Of Father  1983        45       59      44      80
# 4                    For His Dreams  1965        58       64      74      79
# 5                Don't Need My Girl  2003        35       92      57      12
# 6                  Rodeo And Choice  2018        72       57      13       0
# 7                    Dirt And Heart  1963        12       89      58      34
# 8                    Storm And Fire  1979        83       84      54      81
# 9            You're My One And Only  1934         4       73      39      25
# 10                      You Cheated  1986        14       45      38      14
# ...

# %%
# Connect to database (Note: The package psychopg2 is required for Postgres to work with SQLAlchemy)
db_string = f"postgres://postgres:{db_pwd}@127.0.0.1:5432/Platinum_Lyrics"

engine = create_engine(db_string)

# %%
mock_data_df.to_sql(name='mock_data', con=engine)

# %%
print(engine.table_names())
# Out:
# ['words', 'lyrics', 'mock_data']

# %% [markdown]
# ### The Database Platinum_Lyrics now contains the mock_data table that we'll use for machine learning
